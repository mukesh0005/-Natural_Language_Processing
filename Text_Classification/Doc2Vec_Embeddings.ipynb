# %% [markdown]
# - Direct representation for the entire document (sentence/paragraph) rather than each word.

# %% [markdown]
# ### Sentimental Analysis - Emotion in Text

# %%
import pandas as pd
import nltk
nltk.download('stopwords')
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\veera\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('./data/train_data.csv')
df.head()
# Out:
#     sentiment                                            content
# 0       empty  @tiffanylue i know  i was listenin to bad habi...
# 1     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm               wants to hang out with friends SOON!
# 4     neutral  @dannycastillo We want to trade with someone w...

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# worry         7433
# neutral       6340
# sadness       4828
# happiness     2986
# love          2068
# surprise      1613
# hate          1187
# fun           1088
# relief        1021
# empty          659
# enthusiasm     522
# boredom        157
# anger           98
# Name: count, dtype: int64

# %%
sents = ['love','sadness','happiness']
df_sub = df[df['sentiment'].isin(sents)]
len(df_sub)
# Out:
# 9882

# %% [markdown]
# ### Text Preprocessing

# %%
tweeter = TweetTokenizer(strip_handles=True,preserve_case=False)
mystopwords = set(stopwords.words("english"))

# %%
def preprocess_corpus(texts):
    def remove_stops_digits(tokens):
        #Nested function that removes stopwords and digits from a list of tokens
        return [token for token in tokens if token not in mystopwords and not token.isdigit()]
    #This return statement below uses the above function to process twitter tokenizer output further. 
    return [remove_stops_digits(tweeter.tokenize(content)) for content in texts]

# %%
x = preprocess_corpus(df_sub['content'])
y = df_sub['sentiment']
print(len(x),len(y))
# Out:
# 9882 9882

# %%
train_data, test_data, train_cats, test_cats = train_test_split(x,y,random_state=1234)

# %% [markdown]
# - TaggedDocument class. It’s used to represent a document as a list of tokens followed by a “tag,” which in its simplest
# form can be just the filename or ID of the document.

# %%
train_data
# Out:
# [['love', '.'],
#  ['thanks',
#   ',',
#   'mandy',
#   '!',
#   'good',
#   'sister',
#   '.',
#   'may',
#   'true',
#   ',',
#   'unfortunately',
#   'road',
#   'tires',
#   "can't",
#   'say',
#   '.'],
#  ['oops', ',', 'drunken', 'stupor', 'lol', '.', 'ima', 'check'],
#  ['cuddling', '.', 'girl', 'cuddles', 'fun', 'soft'],
#  ['understands', 'long', 'hour'],
#  ['scramming', 'little', 'early', '.', 'nibs', 'sounds', 'pathetic', '.'],
#  ['*',
#   'sigh',
#   '*',
#   "i'm",
#   'going',
#   'bed',
#   '...',
#   'feel',
#   'right',
#   'anymore',
#   '...'],
#  ['ok', '...', '.'],
#  ['http://twitpic.com/4vd89',
#   '-',
#   'good',
#   'looking',
#   'cpl',
#   '!',
#   '!',
#   "can't",
#   'wait',
#   'see',
#   'kind',
#   'kids',
#   "y'all",
#   '!'],
#  ["caan't",
#   'iht',
#   'earlier',
#   '?',
#   'icant',
#   'wait',
#   'long',
#   '.',
#   'ahar',
#   '.',
#   '(:'],
#  ['boy',
#   'leaving',
#   'summer',
#   ',',
#   'going',
#   'stay',
#   'grandparents',
#   '..',
#   "i'm",
#   'gonna',
#   'miss',
#   '!',
#   '!'],
#  ['thanks', 'ff', 'think', 'start'],
#  ['yeah',
#   'double',
#   'edged',
#   'sword',
#   '.',
#   'guess',
#   'dead',
#   'new',
#   'stories',
#   '?'],
#  ['got', 'new', 'followers', 'yesterday', '!', 'yay', 'need', 'til'],
#  ['lol', 'seriously', '.', 'fail', '.', '::', 'sigh', '::'],
#  ['need',
#   'come',
#   'spend',
#   'time',
#   'roof',
#   '-',
#   'miss',
#   '&',
#   'double',
#   'date',
#   'couple',
#   'weeks',
#   '?'],
#  ['watching',
#   'jimmy',
#   'f',
#   '.',
#   'delete',
#   'social',
#   'network',
#   'profiles',
#   'jimmy',
#   'cyber',
#   'time',
#   '.'],
#  ['may', '4th'],
#  ['really',
#   'tired',
#   '.',
#   'work',
#   'whole',
#   'day',
#   'tomorrow',
#   ',',
#   'thought',
#   'depresses',
#   '.',
#   'uncoooool',
#   '...'],
#  ['got', 'stuck', 'traffic', 'jam', 'today', ',', 'one', 'sunburned', 'arm'],
#  ['happy', "mother's", 'day', '!', 'sure', 'say', '<3', ',', 'mum', '.'],
#  ['day', 'nothing'],
#  ['sad', 'nothing', '.'],
#  ['oh',
#   'also',
#   '...',
#   "here's",
#   'clip',
#   'new',
#   'moon',
#   'trailer',
#   ',',
#   "can't",
#   'watch',
#   'cuz',
#   "i'm",
#   'work',
#   '.',
#   'http://bit.ly/wXa9l'],
#  ["i'm", 'awake', ',', 'happy', '!'],
#  ['hahaha', '!', 'snoring', ',', '?'],
#  ['thank'],
#  ["i'm", 'tired'],
#  ['looking', 'food', 'home', '!', '...', 'nothing'],
#  ['happy', 'mothers', 'day', 'mummy'],
#  ['one',
#   'bad',
#   'days',
#   '...',
#   'migraine',
#   'today',
#   '.',
#   '1st',
#   'since',
#   'neck',
#   'surgery',
#   '1/2',
#   'months'],
#  ['infamous', 'ps3', '=', 'awesome', '.', 'eyes', 'sore', 'though'],
#  ['r',
#   'u',
#   'defensive',
#   'bus',
#   '?',
#   '?',
#   '!',
#   '!',
#   '!',
#   '?',
#   '?',
#   'mean',
#   ',',
#   'make',
#   'sad',
#   '!',
#   '!',
#   '!'],
#  ['every',
#   'saturday',
#   'till',
#   '8/',
#   'work',
#   '.',
#   'sucks',
#   '.',
#   'friday',
#   'monday',
#   'july',
#   '4th',
#   'either',
#   '.'],
#  ['know',
#   'mark',
#   'still',
#   'one',
#   'favorite',
#   'boys',
#   'ever',
#   '.',
#   'nice',
#   'adorable',
#   '.'],
#  ['http://twitpic.com/6714p',
#   '-',
#   'well',
#   'done',
#   'guys',
#   '!',
#   'gonna',
#   'miss',
#   'tweets',
#   '!'],
#  ['shiv', ',', 'place', ',', 'slowly', 'hope'],
#  ['last', 'day', '...', 'back', 'work', 'tomorrow'],
#  ['best',
#   'purchases',
#   'today',
#   'yard',
#   'sales',
#   ':',
#   'large',
#   'dog',
#   'crates',
#   '(',
#   '$',
#   ')',
#   'refrigerator',
#   'office',
#   '(',
#   '$',
#   ')',
#   'buy',
#   'anything',
#   'old'],
#  ['mmm',
#   ',',
#   'pizza',
#   'dinner',
#   '.',
#   'yum',
#   '.',
#   'burnt',
#   'mouth',
#   'though',
#   '..'],
#  ['house',
#   'home',
#   'alone',
#   ',',
#   'playing',
#   'guitar',
#   'guitar',
#   'hero',
#   'loud',
#   '.'],
#  ['working',
#   '930a',
#   '-',
#   '730p',
#   'today',
#   '.',
#   '1.5',
#   'hour',
#   'lunch',
#   '..',
#   '8.5',
#   'hours',
#   'work',
#   '.',
#   'overtime',
#   '=',
#   'good',
#   '.',
#   'fact',
#   "i'm",
#   'already',
#   'dead',
#   'tired',
#   '=',
#   'bad',
#   '.'],
#  ['powerdvd',
#   'want',
#   'play',
#   'pushing',
#   'daisies',
#   'dvd',
#   '.',
#   'want',
#   'screenies',
#   'make',
#   'icons',
#   '!',
#   'copy',
#   'protection',
#   'gone',
#   'bonkers',
#   '?'],
#  ['sky', '.', 'terrestrial', 'analogue'],
#  ['rachael', 'makes', 'want', 'cry'],
#  ['game', '.', 'found', 'late', '.'],
#  ['car',
#   'home',
#   '.',
#   'yay',
#   '!',
#   '$',
#   '613.22',
#   'boo',
#   '!',
#   "i'm",
#   'paying',
#   'mom',
#   'installments',
#   '.',
#   'gave',
#   '$',
#   'today',
#   '.',
#   'need',
#   'win',
#   'lottery',
#   '.',
#   ':\\'],
#  ['wow', '.', 'way', 'discouraged', 'idk', 'anymore', '...', 'fml', '.'],
#  ['bah', 'day', 'ending', 'nicely', 'began'],
#  ['~',
#   'happy',
#   'star',
#   'wars',
#   'day.every',
#   'one',
#   '~',
#   '...',
#   'may',
#   'fourth',
#   '!'],
#  ['propellerheads',
#   'harddrive',
#   'long',
#   '.',
#   'got',
#   'music',
#   'repo',
#   'back',
#   'shape',
#   'felt',
#   'nostalgic'],
#  ['may', '4th', '!', 'happy', 'star', 'wars', 'day', 'twirps', '!', 'rofl'],
#  ['yay', '!', 'joy', 'department'],
#  ['nothing',
#   'trying',
#   'keep',
#   'week',
#   'old',
#   'kitten',
#   'lol',
#   '.',
#   'full',
#   'piss',
#   'vinegar',
#   'morning',
#   '.'],
#  ["i'm", 'going', ',', 'sadly', '.', 'maybe', 'next', 'year', ',', 'eh', '?'],
#  ['ugh',
#   ',',
#   'hungry',
#   'scarfed',
#   'lunch',
#   'even',
#   'thought',
#   'take',
#   'pic',
#   '.',
#   '#feastfriday'],
#  ['got',
#   'dove',
#   'bird',
#   '&',
#   'names',
#   'cats',
#   'example',
#   '"',
#   'small',
#   'hearts',
#   '-',
#   '<3',
#   'fefe',
#   '<3',
#   'lulu',
#   '<3',
#   'paw',
#   '<3',
#   '"',
#   '-',
#   'update',
#   'pics',
#   'later'],
#  ['hi',
#   ',',
#   'recovering',
#   'party',
#   ',',
#   'looking',
#   'forward',
#   'exciting',
#   'bank',
#   'holiday',
#   'around',
#   'diy',
#   'shops',
#   '...',
#   'life',
#   'cant',
#   'get',
#   'much',
#   'better.surely'],
#  ['fight',
#   'club',
#   '10th',
#   'anniversary',
#   're-enacting',
#   '.',
#   'nice',
#   'tattoos',
#   'http://img.suicidegirls.com/media/albums/6/57/13576/658166.jpg'],
#  [],
#  ['darn', '.', 'bacon'],
#  ['love',
#   'idea',
#   'giving',
#   'year',
#   'theme',
#   '.',
#   'year',
#   'new',
#   'beginnings',
#   '!'],
#  ['home',
#   'ice',
#   'cream',
#   'tweet-up',
#   '(',
#   'first',
#   'tweet-up',
#   '!',
#   ')',
#   'pics',
#   'camera',
#   'battery',
#   'died',
#   'last',
#   'night',
#   'forgot',
#   'charge'],
#  ['better',
#   'hudgens',
#   '.',
#   'omg',
#   'song',
#   'came',
#   'shuffle',
#   '.',
#   'would',
#   '-',
#   'city',
#   'high',
#   '.'],
#  ['happy', 'sad', 'may', 'soul', 'rest', 'peace'],
#  ['miss',
#   'way',
#   'much',
#   '...',
#   'cnt',
#   'stop',
#   'thinking',
#   'nite',
#   'nite',
#   'folkkz',
#   '...'],
#  ['like',
#   'mine',
#   'green',
#   'somehow',
#   'taste',
#   'minty',
#   'otherwise',
#   '..',
#   'heh',
#   'heh',
#   '.'],
#  ['yay',
#   'sing',
#   'loud',
#   'wed',
#   ',',
#   'fall',
#   'boy',
#   ',',
#   'time',
#   'low',
#   'cobra',
#   'starship',
#   'friday',
#   'win'],
#  ['cooking', 'microwave', 'pizzas', ',', 'yummy'],
#  ['know',
#   '!',
#   '!',
#   '!',
#   'yopu',
#   'got',
#   'round',
#   'watching',
#   '?',
#   'cried',
#   '!',
#   '!',
#   '!'],
#  ['made', 'work', 'get', 'feelin', 'blurgh'],
#  ['sun', 'making', 'happy', '=]', 'shame', 'work', 'tonight', 'x'],
#  ['awoke',
#   'completely',
#   'freaked',
#   'frantic',
#   'frenzy',
#   '.',
#   'going',
#   'long',
#   'night',
#   '.'],
#  ['head',
#   'ache',
#   "tom's",
#   'call',
#   'time',
#   'really',
#   'early',
#   'shows',
#   'start',
#   '2:30',
#   'pm',
#   '.',
#   'recovered',
#   'like',
#   '+',
#   'photos',
#   'already',
#   '...',
#   'go',
#   '!'],
#  ['bumping', 'air', "supply's", 'greastest', 'hits'],
#  ['sad',
#   'say',
#   'bye',
#   'bye',
#   'beautiful',
#   'mountains',
#   '.',
#   'http://twitpic.com/675ks'],
#  ['im', 'nervous', ':/', 'want', 'gimme', 'bear', 'hug'],
#  ['melted',
#   'maybe',
#   'square',
#   'inches',
#   'skin',
#   '.',
#   'ran',
#   'cold',
#   'water',
#   'min',
#   'two',
#   'iced',
#   'ice',
#   'melted',
#   '.',
#   ',',
#   'hurts'],
#  ['ok',
#   'found',
#   'way',
#   '...',
#   'think',
#   'tonight',
#   "let's",
#   'let',
#   'go',
#   'dance',
#   'time',
#   '!'],
#  ['always',
#   'good',
#   'day',
#   '!',
#   'make',
#   'good',
#   'time',
#   'make',
#   'better',
#   'w',
#   '/',
#   'ur',
#   'morning',
#   'greetings',
#   '!',
#   '!',
#   'thank',
#   '!',
#   '!'],
#  ['got', 'really', 'sick', 'today', 'text', 'later', '.', 'nap', 'time'],
#  ['sunny', 'day', 'brights', 'day', '!'],
#  ["there's", 'year', 'waiting', 'list', 'get', 'appointment', '.'],
#  ["laura's", 'gone', 'weekend', ',', 'miss', 'already', '!'],
#  ['pleasure', 'sorry', 'hear', 'pollen', 'thing'],
#  ['dreaming', 'weekend', '...', 'awake', '!'],
#  ['impossible'],
#  ['http://twitpic.com/4jcf1',
#   '-',
#   'looks',
#   'great',
#   '!',
#   'love',
#   'way',
#   'bottom',
#   '.'],
#  ['money', 'phone'],
#  ['haha', 'check', 'site', 'got', 'good', 'ones'],
#  ['got',
#   'go',
#   'shopping',
#   'wife',
#   "tesco's",
#   '.',
#   'knew',
#   'day',
#   'going',
#   'well',
#   '.'],
#  ['wish',
#   'sun',
#   'would',
#   'come',
#   '...',
#   'guess',
#   'matter',
#   'since',
#   "i'm",
#   'work',
#   "can't",
#   'enjoy',
#   'anyways'],
#  ["i'll", 'give', 'hug', 'see', 'tell', 'say', 'hi'],
#  ['wow',
#   ',',
#   'nothing',
#   'like',
#   'sale',
#   'perk',
#   "girl's",
#   'evening',
#   ',',
#   'huh',
#   '!'],
#  ['sorry'],
#  ['lisa',
#   'rogers',
#   'carpool',
#   'alltime',
#   'fave',
#   '!',
#   '!',
#   'good',
#   'work',
#   '!',
#   '!'],
#  ["can't",
#   'get',
#   'one',
#   'either',
#   'dog',
#   '.',
#   "i'm",
#   'pretty',
#   'sure',
#   'bunny',
#   'survive',
#   'struggle',
#   'tom'],
#  ['wreck',
#   '.',
#   'getting',
#   'real',
#   'sore',
#   '.',
#   'fault',
#   'insurance',
#   '.',
#   'planning',
#   'go',
#   'wedding',
#   'tonight'],
#  ['ps', ':', 'wish', 'coming', 'tonight', '.'],
#  ["can't",
#   'figure',
#   'reply',
#   'tumblr',
#   'sorry',
#   '!',
#   'get',
#   'nyc',
#   '6/4',
#   "can't",
#   'go',
#   'events',
#   'b4'],
#  ['omg', 'finish', '?', '?'],
#  ['cool', "i'm", 'glad', '.', 'save', 'tea'],
#  ['congratulation', 'icehockey', 'victory', 'switzerland', '..'],
#  ['know', 'im', 'inlove', 'actually', '..'],
#  ["dosen't", 'want', 'go', 'work', 'tomorrow'],
#  ['gawd', '!', '.', 'dream', 'actually', 'happened', 'last', 'night', '...'],
#  ['hips',
#   'wide',
#   'rock',
#   'mario',
#   'kart',
#   'shorts',
#   'bone',
#   'structure',
#   'year',
#   'old',
#   'boy',
#   '?'],
#  ['pretty', 'good', '.', 'kind', 'depressing', 'though'],
#  ['good',
#   'morning',
#   ',',
#   'sis',
#   '!',
#   'alas',
#   ',',
#   "it'll",
#   'time',
#   'say',
#   'goodnight',
#   'soon',
#   '.'],
#  ['havent', 'ages', 'sorry', 'twitter', '..', 'tweetdeck', 'broken'],
#  ['fell', 'asleep', 'waiting', 'ride', '!'],
#  ['playing', 'pacman', 'itouch', '!', 'lol'],
#  ['http://twitpic.com/66l83', '-', 'liked', 'old', 'ruby', 'best', '.'],
#  ['bored', '...', 'miss', 'everybody', 'already'],
#  ['still', 'awake', '!', '!', '!', 'smh', '...', 'sucks', '!', '!', '!'],
#  ['hahahaha', 'train', '?', 'want', '!', 'wild', 'ride'],
#  ['going',
#   'post',
#   'office',
#   'try',
#   'sort',
#   'whole',
#   'ebay',
#   'hacker',
#   'thing'],
#  ['supernatural', 'good', 'loved', '.'],
#  ['may', '4th', 'happy', 'star', 'wars', 'day', '!', '!', '!'],
#  ['raining',
#   "i'm",
#   'stuck',
#   'inside',
#   'working',
#   'today',
#   "i'd",
#   'probably',
#   'peed',
#   'sunny',
#   'outside',
#   ',',
#   "i'm",
#   'ok',
#   'rain'],
#  ['wish', 'nicky', 'home'],
#  ['missing', 'bham'],
#  ['ahhhhh', 'well', 'least', "i'm", '!'],
#  ['good',
#   'morning',
#   ',',
#   'however',
#   'night',
#   'time',
#   ',',
#   'bed',
#   '*',
#   'hugs',
#   '*',
#   'great',
#   'day'],
#  ['damn', 'call'],
#  ['http://twitpic.com/48gy0',
#   '-',
#   "he's",
#   'well',
#   'cooool',
#   ';)',
#   'lovve',
#   'ro',
#   '&',
#   'co',
#   'shoooow'],
#  ['http://twitpic.com/4jj4j',
#   '-',
#   'birthday',
#   'breakfast',
#   '!',
#   'yummm',
#   '-',
#   'chai',
#   '&',
#   'apple',
#   'fritter'],
#  ['good', 'morning', 'tweeties'],
#  ['wut', 'itell', 'u', 'yesterday', 'lol'],
#  ['mom',
#   'nurse',
#   'practitioner',
#   '&',
#   'spent',
#   'entire',
#   'life',
#   'devoted',
#   'field',
#   '.',
#   'good',
#   'ones',
#   'deserve',
#   'recognized',
#   '!',
#   "i'll",
#   'follow'],
#  ['nice', 'day', 'stuck', 'inside', '!', '!'],
#  ['really',
#   'sorry',
#   'becausei',
#   'looking',
#   'forward',
#   '..',
#   'thought',
#   'itd',
#   'fun',
#   'u',
#   'wanted',
#   'hear',
#   'it.iowe',
#   'u',
#   'beer',
#   '.'],
#  ['hahah',
#   '!',
#   '!',
#   'except',
#   'haley',
#   'gets',
#   'hit',
#   'car',
#   'yay',
#   'leyton',
#   '!'],
#  ['watching', '"', 'knowing', '"', 'lovin'],
#  ['needs',
#   'water',
#   ',',
#   'paper',
#   'towels',
#   'coke',
#   'store',
#   'feels',
#   'sick',
#   'go',
#   'get'],
#  ['omg',
#   '@',
#   'hair',
#   'salon',
#   '.',
#   '*',
#   'tears',
#   '*',
#   'hope',
#   'get',
#   'soon',
#   '.',
#   'watching',
#   'real',
#   'house',
#   'wives',
#   'nyc',
#   '.'],
#  ['fuck',
#   '!',
#   "i'm",
#   'already',
#   'thinking',
#   'shows',
#   "i'm",
#   'going',
#   'miss',
#   "i'm",
#   'broke',
#   '.'],
#  ['go',
#   ',',
#   'uploading',
#   'photos',
#   'email',
#   'would',
#   'ten',
#   'tenenen',
#   'tenen',
#   '..',
#   'done'],
#  ['good', 'morning', 'everyone'],
#  ['nothings',
#   'better',
#   'going',
#   'chinese',
#   'supperinn',
#   'fave',
#   'cousins',
#   '1am'],
#  ['enjoy', '!', 'family', 'trumps', 'everything'],
#  ['got',
#   'full',
#   'day',
#   'work',
#   'today',
#   '.',
#   "can't",
#   'wait',
#   'tell',
#   'get',
#   'home',
#   'beer',
#   'tv',
#   'time',
#   'got',
#   'make',
#   'money',
#   'get',
#   'beers'],
#  ['finally', 'got', 'call', 'marriage', 'counseling', 'days', 'late', '...'],
#  ["he's",
#   'retiring',
#   'tonight',
#   'show',
#   'im',
#   'bummed',
#   '.',
#   'awesome',
#   'ha',
#   '.',
#   'congrats',
#   'dear'],
#  ['go', 'gymnastics', '!', 'last', 'day', 'class', '!'],
#  ['hours', 'im', 'taking', 'aerobics', 'classes', 'min', 'break'],
#  ['um', ',', 'thrown', "'", 'van', 'yesterday', 'taken', 'er'],
#  ['1st',
#   '-',
#   'ty',
#   'follow',
#   'back',
#   '.',
#   '2nd',
#   '-',
#   'grrr',
#   ',',
#   'cuz',
#   'messes',
#   'able',
#   'follow',
#   'others',
#   'u',
#   'want',
#   'ur',
#   '+'],
#  ['sbarro',
#   'dinner',
#   'krispy',
#   'kreme',
#   'dessert',
#   '.',
#   'mmmmm',
#   '!',
#   'healthy',
#   '.'],
#  ['oh',
#   ',',
#   'realize',
#   'well',
#   '-',
#   'already',
#   'work',
#   '-',
#   'today',
#   'still',
#   'car',
#   ',',
#   'ask'],
#  ['safer',
#   'say',
#   'cube',
#   'sphere',
#   '...',
#   'roll',
#   'buddy',
#   '...',
#   'awesome',
#   'time',
#   '...',
#   'esp',
#   '1st',
#   'one'],
#  ['oh',
#   ',',
#   'went',
#   'friend',
#   'myoh',
#   'last',
#   'night',
#   'ran',
#   'tarsier',
#   'pins',
#   '.',
#   'sad',
#   '.',
#   'really',
#   'cute',
#   '.'],
#  ['app', 'said', 'need', '12.1', '.', 'later'],
#  ['tweep', 'tweep', 'haha'],
#  ['got', 'excited', 'thought', 'exhibit', 'sydney', '.'],
#  ['cant', 'girl', 'like', 'whats', 'walet', '?'],
#  ['nope', ',', 'would', 'music'],
#  ['omj',
#   'loved',
#   '...',
#   'good',
#   'laugh',
#   'frankie',
#   'great',
#   'job',
#   ',',
#   'guys',
#   '~',
#   'agnes'],
#  ['silly', '.'],
#  ['unfortunately', 'leave', 'house', 'time'],
#  ['want', 'watch', 'naruto', 'shippuuden', 'missed', 'episodes', '.'],
#  ['according',
#   'mick',
#   'jagger',
#   ',',
#   'hindu',
#   'ragas',
#   'sfs',
#   'sort',
#   'music'],
#  ['sounds',
#   'good',
#   '.',
#   'appreciate',
#   'suggestion',
#   '.',
#   'week',
#   "we're",
#   'still',
#   'offline',
#   'time',
#   'ask',
#   'refund',
#   '...'],
#  ['pretty',
#   'good',
#   '!',
#   '!',
#   '!',
#   'think',
#   'overdid',
#   'gym',
#   'yesterday',
#   '...',
#   'working'],
#  ['may', 'forth'],
#  ['family',
#   'guy',
#   'reruns',
#   ',',
#   'food',
#   ',',
#   ',',
#   'good',
#   'phone',
#   'conversations',
#   'ah',
#   ',',
#   'saturdays',
#   '.'],
#  ['made', 'day', ':', 'http://tinyurl.com/cumqmv'],
#  ['epic', 'moment', '!', 'hahahha', 'swear', '..', 'really', 'wanna', 'see'],
#  ['aww', 'sweet'],
#  ['washer',
#   'se',
#   'chingo',
#   'ha',
#   'ha',
#   '!',
#   '!',
#   "i'm",
#   'busting',
#   'grandma',
#   'lucia',
#   'waaaaay',
#   'back',
#   'early',
#   "'",
#   'lol'],
#  ['got',
#   'crush',
#   'issue',
#   'tomorrow',
#   'friend',
#   'going',
#   'india',
#   'whole',
#   'summer',
#   'im',
#   'back',
#   'sad',
#   '.'],
#  ['far',
#   '(',
#   'exception',
#   'rain',
#   ')',
#   ',',
#   'morning',
#   'great',
#   '.',
#   'let',
#   'dampen',
#   'day'],
#  ['going',
#   'picnic',
#   'dad',
#   '-',
#   'atleast',
#   'persauded',
#   'idea',
#   'walking',
#   '&',
#   'cycling',
#   '.',
#   'yum',
#   ',',
#   'special',
#   'k',
#   '.'],
#  ['dinner',
#   'awesome',
#   '.',
#   'im',
#   'happy',
#   'mom',
#   'enjoyed',
#   'bday',
#   'able',
#   'spoil',
#   'yay',
#   'lol'],
#  ['happy', 'camper', 'good', 'day', '...'],
#  ['live',
#   'live',
#   '!',
#   ')',
#   'dj',
#   'jayem',
#   'b2b',
#   'e',
#   '.',
#   '.',
#   'r',
#   'click',
#   ':',
#   'http://www.krisisdnb.com/listen.asx'],
#  ['spring', 'show', 'super', 'fun', '!'],
#  ['good', '(', 'boy', ')', 'friend', 'like'],
#  ['gotta',
#   'go',
#   'twitterers',
#   '(',
#   '?',
#   ')',
#   'stupid',
#   'sister',
#   'wants',
#   'go',
#   'facebook',
#   'oging',
#   'montreal',
#   '2morrow',
#   'wont',
#   '!',
#   'bye',
#   '!',
#   '!',
#   'xoxox',
#   '<3'],
#  ['school', 'w', '.', 'linda', 'nothing', ';', 'miss'],
#  ['pleasure', 'playing', 'guitar', '!', 'fun'],
#  ['miss', 'baby'],
#  ['haha', 'fail', 'remember', 'sohcahtoa', 'xd'],
#  ['mmm',
#   '...',
#   'hot',
#   'chocolate',
#   ',',
#   'ugboots',
#   'topgear',
#   '...',
#   'life',
#   'good',
#   '.'],
#  ['dreary',
#   'bus',
#   'ride',
#   'home',
#   '.',
#   'im',
#   'rubbing',
#   'eyes',
#   'least',
#   'spend',
#   'day',
#   'school',
#   '.',
#   'hrs',
#   'well',
#   'spent'],
#  ['need', 'watch', 'star', 'trek'],
#  ['amazing',
#   '!',
#   'concert',
#   ',',
#   'city',
#   ',',
#   'everything',
#   '.',
#   'really',
#   'awesome',
#   'trip'],
#  ['awoooogahhhhhh',
#   '!',
#   '!',
#   '!',
#   'heheee',
#   'hope',
#   'get',
#   'decently',
#   'priced',
#   'breakfast',
#   'real',
#   'quick',
#   ',',
#   'david'],
#  ['cant',
#   'sleep',
#   '!',
#   'couldnt',
#   'sleep',
#   'last',
#   'night',
#   'eather',
#   '!',
#   '*',
#   'wabble',
#   'wabble',
#   '*'],
#  ['thanks',
#   'tip',
#   '!',
#   'unfortunately',
#   'major',
#   'crash',
#   'https',
#   'site',
#   ',',
#   'extplorer'],
#  ['good', 'morning', 'world', '.'],
#  ['time', 'get', 'ready', 'work'],
#  ['bit', 'motorcycle', 'trip', 'today', '!'],
#  ['another', 'song', 'makes', 'cry', 'cry', 'day', 'night', 'long', '.'],
#  ['weekend',
#   ',',
#   'bought',
#   'lost',
#   'odyssey',
#   ',',
#   'yay',
#   '-',
#   '-',
#   '-',
#   'however',
#   ',',
#   "rrod'ed",
#   'second',
#   'time'],
#  ['aww',
#   'im',
#   'sorry',
#   'im',
#   'home',
#   'hope',
#   'ok',
#   'love',
#   'ya',
#   'wifey',
#   '<3',
#   'xx'],
#  ['everything', 'annoying', 'today'],
#  ['atm',
#   '?',
#   'http://twitpic.com/4jmeh',
#   'oh',
#   'yeah',
#   '.',
#   'apple',
#   'juice',
#   "i'm",
#   'rebel',
#   '!'],
#  ['ready'],
#  ['awsome', '...', 'know', ',', 'know', ',', 'know', '!'],
#  ['youtube', 'account', '.'],
#  ['sick', 'tired', 'rain'],
#  ['get', 'new', 'one', 'nxt', 'wk', '!', '!', '!'],
#  ['still', 'white', 'despite', 'ages', 'sun'],
#  ['looks',
#   'like',
#   'dialed',
#   'lot',
#   '...',
#   'payed',
#   'attention',
#   'small',
#   'important',
#   'details',
#   'gameplay',
#   '...',
#   'still',
#   'blood',
#   'tho'],
#  ['"',
#   '...',
#   'never',
#   'alone',
#   ';',
#   'love',
#   ',',
#   "that's",
#   'really',
#   'know',
#   '...',
#   '"'],
#  ['im', 'cold', 'still', 'cant', 'find', 'hoodie'],
#  ['san',
#   'diego',
#   '!',
#   'move',
#   '!',
#   'although',
#   'whether',
#   'right',
#   'pretty',
#   'cold',
#   '.',
#   'im',
#   'waiting',
#   'suck',
#   'go',
#   'surf',
#   'love'],
#  ['good', 'morning', 'thanks', 'retweet'],
#  ['yet', '...', 'sorry'],
#  ['last', 'day', 'high', 'school', "i'm", 'gonna', 'miss', 'friends'],
#  ['thanks', 'finding', '!', 'wonderful', 'evening', '!'],
#  ['see', 'hannah', 'klein', '!', '.', 'lookin', 'good', 'today'],
#  ['hiyaaaaaa',
#   'got',
#   'back',
#   'scan',
#   '!',
#   'wow',
#   ',',
#   'amazing',
#   ',',
#   'cried',
#   'haha',
#   ',',
#   'xx'],
#  ['great', '!', 'wonderful', 'first', 'day'],
#  ['sitting', 'traffic', 'trying', 'escape', 'campus', 'feeling', 'hellish'],
#  ['increasingly',
#   'convinced',
#   'moderately',
#   'lactose-intolerant',
#   '-',
#   'given',
#   'deep',
#   'abiding',
#   'love',
#   'cheese',
#   ',',
#   'totally',
#   'sucks'],
#  ['yooo', '!', 'rainin', 'dumb', 'hard', '.'],
#  ['happy', 'landed', 'safely', ',', 'miss', 'already', 'http://myloc.me/205R'],
#  ['im', 'tired', ',', 'bored', 'sad.what', 'great', 'evening', '!'],
#  ['finally', 'done', 'project', '!', '3:12', 'haha', 'goodnights', '!', '<3'],
#  ['sell', 'medieval', 'trading', 'pavillion', '...', 'v', 'sad'],
#  ['little', 'sister', 'told', 'double', 'chin', 'aww'],
#  ['thanks', 'mama', '!', 'absolutely', 'adore'],
#  ['.',
#   'says',
#   'gives',
#   'excuse',
#   'sleep',
#   'bed',
#   '!',
#   'lol',
#   "they're",
#   'different',
#   'sizes',
#   'would',
#   'switched',
#   '.'],
#  ['love', 'nose', 'kisses'],
#  ['wish', 'could', 'take', 'pillow', 'school', '.', 'dead', 'serious', '.'],
#  ['today', '!', 'work', 'tomorrow'],
#  ['cab', 'slow', 'probably', 'miss', 'first', 'beer', '...'],
#  ['oh',
#   'ok',
#   ',',
#   'thanks.dont',
#   'know',
#   'courthouse',
#   'id',
#   'either',
#   ',',
#   "i'll",
#   'learn',
#   'though.any',
#   'nkotb',
#   '?',
#   'twitter',
#   'stole',
#   'pic',
#   'hates'],
#  ['peter',
#   '&',
#   'gordon',
#   'morning',
#   '->',
#   ',',
#   'go',
#   'pieces',
#   'wanna',
#   'hide',
#   '/',
#   'go',
#   'pieces',
#   'almost',
#   'die',
#   '/',
#   'ever',
#   '...',
#   '?',
#   'http://blip.fm/~5yk38'],
#  ['miss',
#   'place',
#   ',',
#   'miss',
#   'wegmans',
#   'even',
#   '.',
#   'whole',
#   'foods',
#   '!',
#   '=',
#   'wegmans'],
#  ['sweet', '!', 'thanks', '!'],
#  ['may', '4th', '!', 'hahahaha', 'neverrr', 'get', 'old'],
#  ['ah',
#   'bibisita',
#   'ka',
#   'kina',
#   'gq',
#   'bukas',
#   'sasama',
#   'ka',
#   'sa',
#   'rushers',
#   'eb',
#   '?',
#   'able',
#   'visit',
#   'jumpstart',
#   'tom',
#   'coz',
#   'something'],
#  ['pissing', 'letting', 'follow', 'ericka'],
#  [',',
#   'sadly',
#   '.',
#   'first',
#   'rodeo',
#   ',',
#   'dear',
#   ',',
#   'suspect',
#   'learned',
#   'lesson',
#   '?'],
#  ['yahoo',
#   '!',
#   'great',
#   '!',
#   'always',
#   'nice',
#   'hear',
#   'successful',
#   'stories',
#   '!'],
#  ['regret',
#   'going',
#   'movie',
#   'audition',
#   'today',
#   'seems',
#   'like',
#   'neighbors',
#   'gonna',
#   'get',
#   'call',
#   'back',
#   '.',
#   'http://myloc.me/21RK'],
#  ['loves', 'mr', '.', 'oh', 'much', 'days', '!', '!'],
#  ['holy',
#   'wow',
#   ',',
#   'think',
#   "could've",
#   'slept',
#   'day',
#   '!',
#   'soooo',
#   'tired',
#   '.'],
#  ['boo', 'season', 'finales', '..'],
#  ['ooc',
#   ':',
#   'thanks',
#   '!',
#   'ugh',
#   '...',
#   'bad',
#   ',',
#   'bad',
#   'day',
#   "i've",
#   '.',
#   'damn',
#   '.'],
#  ['chillin', 'promoting', 'muzik', '...', 'eating', 'lmaao'],
#  ['neat', 'hearing', 'u', 'kiddshow', 'today', 'wish'],
#  ['busy', 'work', '.', 'back', 'loves', '!'],
#  ['tgif',
#   '!',
#   '!',
#   'gorgeous',
#   'day',
#   'reno',
#   'today',
#   '.',
#   "i'm",
#   'stuck',
#   'inside',
#   '.'],
#  ['probably', '.', 'sucks', '.'],
#  ['pics', 'arent', 'working', 'twitter'],
#  ['hummmmm',
#   '...',
#   'ohh',
#   'miss',
#   'much',
#   '!',
#   '!',
#   '!',
#   'realy',
#   ',',
#   'hope',
#   'nice',
#   'friends',
#   ',',
#   'like',
#   'us',
#   ':]'],
#  ['shouldnt',
#   ',',
#   'im',
#   'happy',
#   'enjoyed',
#   'cos',
#   'im',
#   'thoughtful',
#   'like',
#   'see',
#   ',',
#   'yaya',
#   'hav',
#   'followers',
#   'woop'],
#  ['sucks',
#   '!',
#   "i'm",
#   'going',
#   'summer',
#   'school',
#   '.',
#   'need',
#   'catch',
#   'several',
#   'units'],
#  ['know',
#   '.',
#   'would',
#   'gone',
#   'red',
#   'river',
#   'forgot',
#   'bout',
#   'tired',
#   'work',
#   '.',
#   'need',
#   'donut',
#   'hole',
#   'eating',
#   'date',
#   'soon',
#   '!'],
#  ['hello', 'pal', '..', 'nice', 'c', 'u', 'today', '...', 'gr8', 'week'],
#  ['going', 'gold', 'coast', 'mothers', 'day', 'lunch'],
#  ['adventure',
#   'say',
#   'least',
#   '.',
#   "i've",
#   'nicer',
#   'parts',
#   'norf',
#   'london',
#   'stick',
#   'south',
#   'today'],
#  ['wait',
#   'red',
#   ',',
#   'could',
#   'ages',
#   '.',
#   'know',
#   'mean',
#   ',',
#   'though',
#   '.',
#   'really',
#   'looking',
#   'new',
#   'job'],
#  ['awh',
#   'tom',
#   ',',
#   'thats',
#   'really',
#   'cute',
#   '.',
#   'love',
#   'guys',
#   'really',
#   ',',
#   "'",
#   'cause',
#   'care',
#   'fans',
#   'x'],
#  ['weathers',
#   'let',
#   'morning',
#   '...',
#   'ugh',
#   '!',
#   '...',
#   'hada',
#   'gd',
#   'nite',
#   'tho',
#   '!'],
#  ['unpacking',
#   'new',
#   'toy',
#   'arrived',
#   'studio',
#   'right',
#   'called',
#   'tc',
#   'finalizer',
#   '.',
#   "can't",
#   'wait',
#   'check',
#   'sounds',
#   '!',
#   '!',
#   '!'],
#  ['wondering', 'friends', 'went', '...'],
#  ["i'm",
#   'gonna',
#   'miss',
#   'show',
#   'whitby',
#   'weekend',
#   '!',
#   'btw',
#   'love',
#   'show',
#   '!',
#   'radio',
#   'always',
#   '!',
#   'ly',
#   'x'],
#  ['pfftt', '...', 'wish', '.', 'time', 'though', '.'],
#  ['good',
#   'mornin',
#   "'",
#   'jason',
#   '!',
#   'ready',
#   'fresh',
#   'new',
#   'week',
#   'well',
#   '!'],
#  ['exams', '.', 'thennn', 'sexy', 'time', '.'],
#  ['heat', '!', '!', '!'],
#  ['addict',
#   '?',
#   '?',
#   'okay',
#   'admit',
#   'need',
#   'help',
#   '...',
#   'writing',
#   'hits',
#   'big',
#   'bro',
#   '.',
#   'really',
#   'really',
#   '*',
#   'smile',
#   '*'],
#  ['come', 'back', 'canada', 'soon', "we'll", 'miss', '!', '!'],
#  ['good', 'day', '...', 'havent', 'good', 'week', 'forreal', '!', '!'],
#  ['thanks',
#   'kashi',
#   '!',
#   'thinking',
#   'day',
#   'mad',
#   'disservice',
#   'taking',
#   'ur',
#   'classes',
#   '.'],
#  ['demi',
#   'pretty',
#   'bangs',
#   'everything',
#   '.',
#   'look',
#   'grown',
#   'picture',
#   'liked',
#   'bangs',
#   '.'],
#  ['misses', 'baby', '.'],
#  ['oooh', 'ok', '.', 'thought', 'losing', 'mizmind'],
#  ['really',
#   'mad',
#   'forgetting',
#   'may',
#   'deadline',
#   '40,000',
#   'mile',
#   'award',
#   'trips',
#   'south',
#   'america'],
#  ['thank', 'much', ',', "i'm", 'glad', 'like', '!'],
#  ['couuuurse', 'fika', "i'll", 'pray', 'thes', 'best', '.'],
#  ['reviews',
#   'done',
#   ',',
#   'new',
#   'sentences',
#   ',',
#   '+',
#   'iknow',
#   'done',
#   'wow',
#   'role'],
#  ['thankyou',
#   'short',
#   'stack',
#   'bringing',
#   'second',
#   'sydney',
#   'show',
#   ',',
#   ',',
#   'im',
#   'going',
#   'im',
#   'thankful',
#   'guys',
#   'good',
#   'ur',
#   'fans',
#   '.'],
#  ['long',
#   'day',
#   '-',
#   'matinee',
#   'evening',
#   'show',
#   '.',
#   'sad',
#   'tomorrow',
#   ':',
#   'last',
#   'ever',
#   'welsh',
#   'college',
#   'show'],
#  ['well',
#   ',',
#   'nice',
#   'thought',
#   'lasted',
#   '.',
#   'maybe',
#   "he'll",
#   'leave',
#   'properly',
#   'next',
#   'time',
#   '*',
#   'crosses',
#   'fingers',
#   '*'],
#  ["i've",
#   'begged',
#   'mum',
#   'lt',
#   'get',
#   'attic',
#   '..',
#   'wont',
#   'let',
#   'waaa',
#   '...',
#   'yes',
#   ',',
#   'spoilt',
#   '!',
#   'hehe',
#   '!'],
#  ['missed', 'chicago', 'show', 'boo', '.'],
#  ['happy', 'early', 'mothers', 'day', '!', '!', '!'],
#  ['happy', 'birthday', '!', 'hope', 'well', 'great', 'birthday', 'day'],
#  ['repeatedly',
#   'rubs',
#   'thumbs',
#   'softly',
#   'lovingly',
#   'upon',
#   'new',
#   'sarah',
#   'rayne',
#   'novel',
#   '.',
#   'sigh',
#   ',',
#   'paperback',
#   '.',
#   "i'm",
#   'potrait',
#   'profound',
#   'bliss'],
#  ["can't", 'wait', 'hear', 'evp', '!', 'cuuuute', 'picture', '.'],
#  ['never',
#   'noticed',
#   'right',
#   '!',
#   'guess',
#   "that's",
#   'heart',
#   'always',
#   'dreaming',
#   'travel',
#   '...'],
#  ['hate',
#   ',',
#   'fleetwood',
#   'favorite',
#   'band',
#   '...',
#   "i'm",
#   'jealous',
#   'ok',
#   'still',
#   'love',
#   'haha'],
#  [':',
#   'comes',
#   'seen',
#   "i'm",
#   'excited',
#   ',',
#   'hope',
#   'gets',
#   'love',
#   'interest',
#   'soon',
#   ',',
#   'tell',
#   '!'],
#  ['douchie',
#   '?',
#   'lol',
#   '...',
#   'thats',
#   'hilarious',
#   'man',
#   '.',
#   'headache',
#   'meeting',
#   '.'],
#  ['another', 'rainy', 'day'],
#  ["g'night", 'world', '.', 'vacations', 'end', 'day', '.'],
#  ['happiest', 'birthdays', 'kat'],
#  ['waitin',
#   'dr',
#   'dee',
#   '...',
#   'lunch',
#   'beautiful',
#   'lady',
#   'gym',
#   '...',
#   '(',
#   'yeah',
#   'need',
#   'loose',
#   ')'],
#  ['happy', 'star', 'wars', 'day'],
#  ['still', 'shout', 'spider'],
#  ['looks', 'like', 'got', 'new', 'job'],
#  ['hey',
#   'babe',
#   ',',
#   'nothing',
#   'much',
#   'tryin',
#   'see',
#   'imma',
#   'work',
#   'today',
#   'lol',
#   ',',
#   'look',
#   'like',
#   'load',
#   'isnt',
#   'bad',
#   '.'],
#  ['really', '?', '?'],
#  [',', "i'd", 'love', 'takers', 'yet'],
#  ["can't", 'chat', 'since', 'go', 'school', 'http://tinyurl.com/mf88dz'],
#  ['guess', 'talking', 'orlando', 'magic', '!', 'nothing', 'magical'],
#  ['want', 'survivor', '!', '!'],
#  ['happy', '#juddday', 'everyone', '!'],
#  ['would', 'like', 'swap', '...', "i'm", 'sitting', 'grumpies'],
#  ['yummmm',
#   'make',
#   'sure',
#   'u',
#   'leave',
#   'im',
#   'home',
#   'cleaning',
#   'working',
#   'mad',
#   'hard'],
#  ['renegades',
#   'last',
#   'day',
#   'today',
#   '...',
#   'well',
#   '...',
#   "he's",
#   'gone',
#   '...',
#   'catch',
#   'gutted',
#   '...',
#   'closest',
#   'came',
#   'greenock',
#   'kilmacolm',
#   '!'],
#  ['wow',
#   '!',
#   'totally',
#   'awesome',
#   '!',
#   'action',
#   'guinea',
#   'pigs',
#   '!',
#   'want',
#   'go',
#   'see',
#   ',',
#   '!',
#   'think',
#   "we'd",
#   'allowed',
#   'take',
#   'lance',
#   '?'],
#  ['good', 'morning', 'raining', '.'],
#  ['tired', 'anxious'],
#  ['*',
#   'ugh',
#   '*',
#   'miserable',
#   'looking',
#   'day',
#   '.',
#   'degrees',
#   '.',
#   'summer',
#   'go',
#   '?'],
#  ['http://dayna.dreamwidth.org', 'daily', 'random-ness'],
#  ['oh', "that's", 'cool', 'thanks', '!', '!'],
#  ['two',
#   'weeks',
#   'left',
#   'middle',
#   'school',
#   'gig',
#   '.',
#   'full-time',
#   'work',
#   'summer',
#   ',',
#   'teaching',
#   'credential',
#   'begins',
#   'end',
#   'august',
#   '!'],
#  ["i'm",
#   'tantra',
#   ',',
#   'anyone',
#   'kirki',
#   'know',
#   'sad',
#   ',',
#   "i'm",
#   'drowning',
#   'sorrows',
#   ';)'],
#  ['wishing',
#   ',',
#   'watching',
#   'videos',
#   ',',
#   'freezing',
#   'next',
#   'weekend',
#   'bring',
#   'edea',
#   'without',
#   'dying'],
#  ['start', 'least', 'favourite', 'chore', '...', 'mopping', 'floor'],
#  ['http://twitpic.com/664b7',
#   '-',
#   'miss',
#   'bestfriend',
#   ":'(",
#   'left',
#   'school'],
#  ['think', 'trying', 'make', 'feel', 'better', '!'],
#  ['haha',
#   'wow',
#   "there's",
#   'song',
#   'called',
#   "'",
#   'hit',
#   'twitter',
#   "'",
#   'lmao',
#   '.',
#   'okay',
#   "g'night"],
#  ['twitter', 'suck', 'missy', 'love'],
#  ['throat',
#   'hurts',
#   'gonna',
#   'go',
#   'read',
#   'go',
#   'bed',
#   '.',
#   'text',
#   'mee',
#   '!'],
#  ['wish',
#   'wit',
#   '.',
#   'friend',
#   'mine',
#   'r',
#   'well',
#   '.',
#   'weekend',
#   "i'll",
#   'working'],
#  ['thanks', '!', 'funny', 'cause', 'true', '!'],
#  ['well',
#   'movie',
#   'night',
#   'spoilt',
#   'fracked',
#   'disk-happiness',
#   'gone',
#   ',',
#   'time',
#   'sleep'],
#  ['hey',
#   'tom',
#   ',',
#   "i'm",
#   'happy',
#   'enjoying',
#   'brazil',
#   ',',
#   "i'm",
#   'sad',
#   'cuz',
#   "i'm",
#   'goin',
#   'see',
#   'show'],
#  ['school',
#   ';',
#   'victoria',
#   '&',
#   'bryan',
#   '(:',
#   '_',
#   'school',
#   'soon',
#   ',',
#   'sadd'],
#  ['awww', ',', 'remind', 'getting', 'ready', 'ball', '.'],
#  ['look', 'soooo', 'cute', 'sunburned', 'baby', '!', '!', '!'],
#  ['love', 'day', 'school', '-->', 'studyin', "'", 'quietly'],
#  ['sorry', 'hear'],
#  ['sounds', 'like', 'town'],
#  ['wow', '.', "someone's", 'proud', '.'],
#  ['mix',
#   'galaxy',
#   'weekend',
#   '!',
#   'love',
#   '(',
#   ')',
#   'friday',
#   'show',
#   '!',
#   'sweet',
#   '!',
#   'make',
#   'one',
#   'listening'],
#  ['love', 'americana', '-', 'movies', 'see'],
#  ['waiting', 'danny', 'text', 'back', ',', ',', ',', 'xoxo'],
#  ['sad',
#   'roommate',
#   'fry',
#   'chicken',
#   'every',
#   'night',
#   '@',
#   '.',
#   'finished',
#   "tonight's",
#   'batch'],
#  ['sad',
#   'day',
#   ',',
#   'redskins',
#   'release',
#   'jansen',
#   'best',
#   'wishes',
#   '.',
#   'http://twurl.nl/ueivwi'],
#  ['aha',
#   "brother's",
#   'wallpaper',
#   'phone',
#   'dolly',
#   'sheep',
#   'aha',
#   "i'm",
#   'loling',
#   '.'],
#  ['problems',
#   'wih',
#   'pizza',
#   '..',
#   'ii',
#   'love',
#   'much',
#   '..',
#   "i'm",
#   'addicted',
#   'pizza',
#   'dot',
#   'dot',
#   'curve',
#   '.',
#   '>'],
#  ['@',
#   'san',
#   'antonio',
#   'missions',
#   'game',
#   'waitressing',
#   '.',
#   'huge',
#   'crowd',
#   '.',
#   'meaning',
#   'slow',
#   'game',
#   '.'],
#  ['aaarrrgh',
#   '!',
#   'sooo',
#   'want',
#   'see',
#   'msg',
#   'august',
#   'dammit',
#   'decent',
#   'seats',
#   'expensive',
#   '.',
#   'booooooo',
#   'recession',
#   '!'],
#  ['watching', 'bleach'],
#  ['know',
#   "'",
#   'rule',
#   "'",
#   'says',
#   'always',
#   'point',
#   'knife',
#   'away',
#   '?',
#   'learned',
#   'lesson',
#   'one',
#   '!',
#   'straight',
#   'finger',
#   '!'],
#  ["can't", 'wait', 'see', '!'],
#  ['damn', 'missed'],
#  ['oh',
#   "i'm",
#   'sorry',
#   "can't",
#   'even',
#   'imagine',
#   '...',
#   'although',
#   'know',
#   'reality',
#   'soon'],
#  ['well', 'welcome', 'back', 'dark', 'side', '!'],
#  ['mower', 'shopping'],
#  ['time', 'next', 'week', 'hopefully', 'holding', 'lili', 'arms', '!'],
#  ['raining', '..'],
#  ['mallorca',
#   '.',
#   'want',
#   'play',
#   'guitar',
#   'come',
#   'home',
#   "i'm",
#   'going',
#   'buy',
#   'mcfly',
#   'dvd',
#   'first',
#   ':]',
#   ']'],
#  [',',
#   'better',
#   'people',
#   'know',
#   'going',
#   'chiodos',
#   'tonight',
#   ',',
#   'right',
#   '?',
#   'kill',
#   'something',
#   '.'],
#  ['cousin', 'leon', 'born', 'today'],
#  ['miss'],
#  ['oh',
#   'noooooo',
#   '!',
#   '!',
#   '!',
#   "i'm",
#   'sorry',
#   '!',
#   '!',
#   'sucks',
#   'hard',
#   '!'],
#  ['wish', 'yesterday', 'friday'],
#  ['whenever', 'rains', 'hard', 'get', 'motivated'],
#  ['night', 'night', 'twitter', 'loves', 'phone', 'sleep'],
#  ['stupid', 'rain', ',', 'picnic', 'cancelled', 'till', 'tomorrow'],
#  ['yeah', 'daw', '.', 'awww', '...', 'wear', 'mask', 'na', '!'],
#  ['think',
#   'twice',
#   'creative',
#   'blog',
#   '.',
#   'cool',
#   'stuff',
#   '.',
#   'http://www.dontthinktwicecollective.blogspot.com/',
#   'thanks'],
#  ["that's",
#   'good',
#   'hear',
#   '!',
#   'hope',
#   'everything',
#   'fine',
#   '..',
#   'keep',
#   '&',
#   'family',
#   'prayer',
#   '!',
#   'love',
#   'isabela',
#   'uribe'],
#  ['meanie', '!', 'one', 'time', 'go', 'lux', 'wont', '!'],
#  ['wish',
#   'see',
#   'clips',
#   'show',
#   'hosted',
#   '.',
#   'hottie',
#   'shawn',
#   "'",
#   '!',
#   'yes',
#   'still',
#   'hottie',
#   '!'],
#  ['song',
#   'suggestion',
#   '.',
#   'anything',
#   'veronicas',
#   'first',
#   'album',
#   '-',
#   'secret',
#   'life',
#   '...',
#   'would',
#   'good',
#   'choice'],
#  ['glad', 'weekend', '.', 'one', 'week', 'left', 'school', 'kids', '.'],
#  ['listening', 'miley', 'cyrus', 'breakout', 'cd', '!', 'love', '!'],
#  ['wooo', 'fight', '!', '!', '!', 'goooo', 'vicky', ','],
#  ['way', 'home', '.', 'think'],
#  ['everyone', 'left', 'gone', 'bed'],
#  ['aparantly',
#   '#starwarsday',
#   'enjoy',
#   'quite',
#   'know',
#   'kent',
#   'happy',
#   'anywho',
#   '!'],
#  ['put', 'right', 'scrambled', 'egg', 'breakfast', '#fartingloud'],
#  ['hillsong',
#   'tom',
#   '.',
#   'night',
#   ',',
#   "dad's",
#   'birthday',
#   '!',
#   'wish',
#   'could',
#   'see',
#   'bday',
#   'though',
#   '.'],
#  ['.', 'left', 'first', '..', 'left', 'bed', 'look'],
#  ['thought',
#   'one',
#   'best',
#   'heroes',
#   ',',
#   'pitty',
#   'killing',
#   'good',
#   'characters',
#   'use',
#   'thing',
#   '!',
#   '?',
#   'lol'],
#  ['idk', '.', 'original', 'great', '.'],
#  ['susan',
#   'egan',
#   ',',
#   'love',
#   '!',
#   'yeah',
#   ',',
#   'said',
#   'would',
#   'pleasant',
#   'trip',
#   '.'],
#  ['tonight',
#   'last',
#   'night',
#   'jay',
#   'leno',
#   '!',
#   '!',
#   '!',
#   'gonna',
#   'cry',
#   'like',
#   'baby',
#   '!',
#   '!'],
#  ['right', '!', '!', 'aah', 'love', 'demi', 'lovato'],
#  ["can't", 'dm', 'since', 'follow', '.'],
#  ["someone's",
#   'sweet',
#   'tooth',
#   'dying',
#   'somethin',
#   'sweet',
#   "i've",
#   'attacked',
#   'chock',
#   'coated',
#   'tiny',
#   'teddies',
#   'could',
#   'find',
#   'lol'],
#  ['lying', 'new', 'lab', 'pup', 'lap'],
#  ['aarg',
#   ',',
#   'looks',
#   'like',
#   'go',
#   'home',
#   'vegas',
#   'weekend',
#   '.',
#   'much',
#   'maker',
#   'faire'],
#  ['haha',
#   '!',
#   'funny',
#   ',',
#   'mikee',
#   '..',
#   'probably',
#   'mike',
#   "i'll",
#   'ever',
#   'like',
#   '*',
#   'sad',
#   'thoughts',
#   '*'],
#  ['cantttt', '.', 'grandparents', '.'],
#  ['ah',
#   'doesnt',
#   'work',
#   'want',
#   'say',
#   'love',
#   'beach',
#   'girl',
#   ',',
#   'guys',
#   'acee',
#   '!',
#   'england',
#   'loves',
#   '(:',
#   'xx'],
#  ["i'm", 'thinking', 'deserve', 'award', '.', 'big', 'shiny', 'one', '.'],
#  ['ahh',
#   'gtg',
#   'pls',
#   'help',
#   'number',
#   "i'll",
#   'come',
#   'back',
#   'later',
#   'see',
#   'u',
#   'said',
#   'haha',
#   'plz',
#   'thank',
#   'u'],
#  ['wish', 'drems', 'could', 'come', 'true'],
#  ['miss', 'seeing', 'fireflies', '...'],
#  ['funny',
#   'said',
#   "we'd",
#   'never',
#   'make',
#   'look',
#   'far',
#   "we've",
#   'come',
#   '...',
#   'im',
#   'back',
#   'heahhh',
#   '!',
#   'um',
#   '.',
#   'yeah',
#   '.',
#   'school',
#   ':/'],
#  ['beautiful',
#   'night',
#   ',',
#   'im',
#   'stuck',
#   'inside',
#   'feelin',
#   'ill',
#   'instead',
#   'crazzzzzzzy',
#   'ass',
#   'party',
#   '!'],
#  ['wishes', 'pool'],
#  ['happy', 'monday', ',', 'twishers', '!', '!', 'passing', 'coffee', '...'],
#  ['peace', '&', 'quiet', '.', 'enjoy', 'lasts', '!'],
#  ['apparently', "i'm", 'meant', 'take', 'dance', 'lessons'],
#  ['couch', "hungover--don't", 'expect', 'much', 'today'],
#  ['compiment', '?', "i'm", 'glad', 'good', 'time', '.'],
#  ['already',
#   '26.1',
#   'c',
#   'office',
#   '.',
#   'people',
#   'melt',
#   '?',
#   "we're",
#   'fighting',
#   'air',
#   'con',
#   'fans',
#   'help',
#   ',',
#   "can't",
#   'find',
#   'budget'],
#  ['hahaha',
#   'probably',
#   'sorry',
#   '.',
#   "we've",
#   'got',
#   'things',
#   'around',
#   'house',
#   '...',
#   'go',
#   "jared's",
#   'parents',
#   'house'],
#  ['lol',
#   ',',
#   'wen',
#   'mum',
#   'used',
#   'take',
#   'kid',
#   ',',
#   'wud',
#   'always',
#   'eat',
#   'bread',
#   'instead',
#   '!',
#   'haha',
#   '.'],
#  ['probably',
#   ',',
#   'kinda',
#   'expensive',
#   'work',
#   '.',
#   'people',
#   'weekends',
#   ',',
#   'work',
#   '.'],
#  ['way', "dad's", 'sistas', '..', 'r', '.', '.', 'p', '.', 'deb', '..'],
#  ['drinking',
#   'instead',
#   'beer',
#   ':',
#   'airport',
#   'beer',
#   '..',
#   'least',
#   'carbonated',
#   '...',
#   'http://mypict.me/1Zu9'],
#  ['oh',
#   'pw',
#   ',',
#   'done',
#   'wrong',
#   '.',
#   'signing',
#   'time',
#   'ur',
#   "children's",
#   'article',
#   'wrong',
#   '...',
#   'neil',
#   'gaiman',
#   '?',
#   '!',
#   'tease',
#   '.',
#   '#bea'],
#  ['limited',
#   'web',
#   'access',
#   '?',
#   'thought',
#   'europe',
#   'lot',
#   '"',
#   'connected',
#   '"',
#   '.',
#   'regardless',
#   ',',
#   'fun',
#   ',',
#   "i've",
#   'never',
#   'europe'],
#  ['looks',
#   'like',
#   'full',
#   'lincoln',
#   'marathon',
#   'yesterday',
#   '?',
#   'awesome',
#   ',',
#   'hm',
#   'tough'],
#  ['rest',
#   'peace',
#   'adam',
#   '&',
#   'glenn',
#   'epps',
#   '...',
#   'gone',
#   'never',
#   'forgotten',
#   '...',
#   'week',
#   '...',
#   'loud',
#   'da',
#   'air',
#   'ya'],
#  ['going', 'lumberjack', 'party'],
#  ['surely',
#   'knew',
#   'hand',
#   '?',
#   'good',
#   'book',
#   'hand',
#   'held',
#   'essential',
#   '.',
#   'psps',
#   'unless',
#   'charger',
#   '.'],
#  ['helped',
#   'save',
#   'runaway',
#   'dog',
#   '.',
#   'want',
#   'friend',
#   ',',
#   'though',
#   '.'],
#  ['way', 'two', '!', 'ten', 'hours', 'real-ale', 'takes'],
#  ['thanks', 'gourmetcook', '!', 'cold', 'shower', 'help', '.'],
#  ['oh', 'beautiful', 'morning', 'brekky', 'bed'],
#  ['inherent', 'humility'],
#  ['...',
#   ',',
#   'person',
#   'stood',
#   '.',
#   'world',
#   'full',
#   'spineless',
#   'cunts',
#   '.',
#   'makes',
#   'sad'],
#  ['saw',
#   'trailer',
#   'batman',
#   'arkham',
#   'asylum',
#   'play',
#   'joker',
#   '.',
#   "that's",
#   'ps3',
#   'exclusive',
#   '.',
#   'damn',
#   'hurt',
#   '.'],
#  ['haha', '..', 'good'],
#  ['nice', 'weather', 'today', 'alex'],
#  ['rub', '.'],
#  ['appreciate'],
#  ['great', 'album', '..', 'lucky', 'vinyl', '.', '?', 'http://blip.fm/~5jhtv'],
#  ['q', ',', 'dont', 'get', 'love', 'anymore', '?'],
#  ['wait', 'till', 'january', '.', 'life', 'fair', '!'],
#  ['good', 'morning'],
#  ['loving', 'life', 'sydney'],
#  ['grade', '?', "can't", 'daughters', 'grade', 'math', '...', 'soo', 'sad'],
#  ["there's",
#   'nothing',
#   'right',
#   "i'm",
#   'tired',
#   'want',
#   'sleep',
#   '.',
#   'cleaned',
#   'pretty',
#   'good',
#   ',',
#   'proud',
#   '.',
#   'least',
#   "i'd",
#   'good',
#   'janitor'],
#  ['graduation',
#   'tonight',
#   "i'm",
#   'gonna',
#   'miss',
#   'boys',
#   '...',
#   'mikey',
#   ',',
#   'dustin',
#   ',',
#   'miles',
#   ',',
#   'charlie',
#   ',',
#   'travy',
#   ',',
#   'nicky',
#   ',',
#   'john',
#   ',',
#   'jake',
#   ',',
#   'boys',
#   '...',
#   'love',
#   'guys'],
#  ['lame', 'deland', 'favorite', 'people'],
#  ['ready', 'weekend', 'sad', 'office', 'tomorrow', 'morning'],
#  ['know', '.', 'hahah', 'xd', 'cha', 'doin', '?'],
#  ['getting',
#   'ready',
#   'school',
#   '-',
#   'second',
#   'maths',
#   'test',
#   'today',
#   'also',
#   'last',
#   'day',
#   '3rd',
#   'year',
#   '!',
#   '!',
#   'next',
#   'week',
#   'officially',
#   '4th',
#   'year'],
#  ['idk',
#   'lol',
#   'head',
#   'hurts',
#   '.',
#   'rly',
#   'bad',
#   '.',
#   '&',
#   'stomach',
#   '...',
#   'hmm',
#   '...',
#   'personally',
#   ',',
#   'think',
#   '#',
#   'ive',
#   'deal',
#   'wit'],
#  ['nyc', 'right', 'favorite', 'people', 'instead', 'stuck', 'ri', '.'],
#  ['hahahahaha', ',', 'day'],
#  ['saw',
#   'xmen',
#   'origins',
#   'sat',
#   '!',
#   'far',
#   'best',
#   'xmen',
#   'movie',
#   '!',
#   'amazing',
#   '!',
#   '!',
#   '!'],
#  ['lucky', '...', 'get', 'capoeira'],
#  ['sunny', 'day', ',', 'sunny', 'outlook'],
#  ['changed',
#   'hairstyle',
#   ',',
#   'good',
#   'supposed',
#   'n',
#   'wealth',
#   'much',
#   'money',
#   '..',
#   'hate',
#   'hairdresser',
#   '~',
#   '~'],
#  ['sitting',
#   'watching',
#   "britain's",
#   'got',
#   'f',
#   'talent',
#   ',',
#   'watched',
#   'small',
#   'girl',
#   'cry',
#   'sad'],
#  ['listening',
#   ':',
#   'sweet',
#   'talk',
#   '-',
#   'cute',
#   'aim',
#   '/',
#   '/',
#   '/',
#   'considering',
#   'taking',
#   'gameboy',
#   'color',
#   '.',
#   'miss',
#   'chiptune',
#   '.'],
#  ['thanx', 'tom', 'love', 'u', '!', '!', '!', 'great', 'day'],
#  ["that's",
#   'awesome',
#   'dude',
#   ',',
#   'yay',
#   'surprise',
#   'celebrities',
#   '!',
#   'got',
#   'meet',
#   'years',
#   'ago',
#   ',',
#   'soooo',
#   'friendly',
#   '.'],
#  ['stressin',
#   'h-core',
#   '.',
#   'supposed',
#   'cleaning',
#   'room',
#   '.',
#   'feels',
#   'like',
#   'crap',
#   '.'],
#  ['miss',
#   'old',
#   '...',
#   'ha',
#   ',',
#   'ha',
#   '.',
#   "can't",
#   'tell',
#   "person's",
#   'name',
#   '.'],
#  ['wonderful', ',', 'home', 'wedding', '.', 'love', "youre's", '?'],
#  ['like', 'minds', 'evening', ',', 'dear', '!'],
#  ['funny'],
#  ['sounds',
#   'like',
#   'fun',
#   'lol',
#   '.',
#   'least',
#   'still',
#   'hair',
#   'right',
#   '?',
#   'weekend',
#   '?'],
#  ['headaches', 'dumb', '.'],
#  ['ha',
#   'ha',
#   'thanks',
#   'tom',
#   '!',
#   "i'm",
#   'loser',
#   '!',
#   'hopefully',
#   'going',
#   '22nd',
#   'june',
#   'till',
#   '3rd',
#   'july',
#   '...',
#   'date',
#   'u',
#   'goin',
#   '?',
#   'u',
#   'missing',
#   'helen',
#   '?',
#   'x'],
#  ['another', 'david', 'hughes', 'list', '?', "i'm", 'hurt', 'ftw', '!'],
#  ['storm',
#   'acting',
#   '...',
#   'excited',
#   'discussion',
#   'session',
#   'regarding',
#   'social',
#   'media',
#   '.',
#   'scott',
#   'lake',
#   ',',
#   'ceo',
#   'thinksm',
#   ',',
#   'attending',
#   '.'],
#  ['back', 'home', 'gonna', 'miss', 'every', 'one'],
#  ['omg',
#   'realised',
#   'listening',
#   '"',
#   'perfect',
#   'story',
#   '"',
#   'penny',
#   'liked',
#   'dr',
#   'horrible',
#   '!',
#   '!',
#   '!',
#   'damn',
#   'captain',
#   'hammer',
#   '!',
#   'omg',
#   'im',
#   'sad',
#   '!'],
#  ['best',
#   'day',
#   'ever',
#   '.',
#   'met',
#   'greatest',
#   'year',
#   'olds',
#   '.',
#   'never',
#   'see',
#   '..',
#   'ahh',
#   '.',
#   "i'll",
#   'miss',
#   '(',
#   'saw',
#   'hour',
#   'xd',
#   ')',
#   'sad'],
#  ['pretty', 'dang', 'tired', '.', 'chambers', 'class', 'napping', '.'],
#  ['time', 'house', 'chores', '!', 'ugh', '!'],
#  ['late', 'nothin', '...'],
#  ['birthday', 'week', 'today', '!'],
#  ['yes',
#   ',',
#   "that's",
#   'meant',
#   '...',
#   'anything',
#   'turn',
#   'hirigana',
#   ',',
#   'though',
#   '.'],
#  ['happy',
#   "mother's",
#   'day',
#   'mm',
#   'mums',
#   '!',
#   '!',
#   '!',
#   'hope',
#   'lovely',
#   'day',
#   '#mamam'],
#  ['sittin',
#   'home',
#   ',',
#   'hellllllllsssssss',
#   'yeah',
#   'got',
#   'girrrrrl',
#   ',',
#   'boysssss',
#   '&',
#   'mangy',
#   'cats',
#   ',',
#   'good',
#   'time',
#   'life',
#   '.',
#   'goodnight',
#   'twitter'],
#  ['thanks', ',', 'glad', 'agree', 'wth', 'follow', 'policy'],
#  ['.',
#   "i'm",
#   'ill',
#   'attempting',
#   'remember',
#   'lots',
#   ',',
#   'nothing',
#   'going',
#   '.'],
#  ['day', 'hasnt', 'without', 'ur', 'running', 'conversation', 'day'],
#  ['awww', 'cuuuute', 'newborns', 'fun', '!'],
#  ['poor', 'love', 'hope', 'get', 'relax', 'somehow', 'weekend', '.'],
#  ['doggy', 'sad', 'cheer', 'jessie', '!'],
#  ['later',
#   'normal',
#   'morning',
#   ',',
#   'got',
#   'attacked',
#   'swarm',
#   'mini',
#   "fly's",
#   'opening',
#   'veranda',
#   'last',
#   'night',
#   'took',
#   'hour',
#   'get',
#   'rid',
#   '!',
#   '!'],
#  ['didnt',
#   '-',
#   'research',
#   'traffic',
#   'beautiful',
#   'system',
#   'twitter',
#   'approx',
#   '100msg',
#   '/',
#   'second',
#   '..',
#   'mine',
#   'grabs',
#   '6msg',
#   '/',
#   'sec'],
#  ['got', 'bad', 'headache'],
#  ['coffee', 'got', 'cold', 'blah', '!'],
#  ['working',
#   ',',
#   '-',
#   'day',
#   'weekend',
#   ',',
#   'aah',
#   'well',
#   'another',
#   'one',
#   'coming',
#   'weeks'],
#  ['please',
#   'nick',
#   ',',
#   'say',
#   'happy',
#   'birthday',
#   '.',
#   'birthday',
#   'yesterday',
#   '!'],
#  ['sars', 'really', 'got', '.'],
#  ['got', 'fight', 'pavement', '.', 'think', 'poor', 'little', 'knee'],
#  ['two', 'week', 'extension', 'contract', '...', "i'm", 'ready', 'done'],
#  ["can't", "i'm", 'iphone'],
#  ['getting',
#   'one',
#   'lil',
#   "gem's",
#   'ears',
#   'repierced',
#   'work',
#   'today',
#   '-',
#   'definitely',
#   'dreading'],
#  ['happy', 'star', 'wars', 'day', 'everyone', '!', 'may', '4th'],
#  ['well', 'official', 'strep'],
#  ['hahahaha', 'watching', '...', 'miss', 'oceans', '...'],
#  ['woke', 'hiccups', 'came', 'back', '!'],
#  [',', '..', 'oh', 'mint', 'lounge', '...', 'awesome', 'night'],
#  ['frank',
#   'ups',
#   "'",
#   'last',
#   'day',
#   'today',
#   '...',
#   'sad',
#   'see',
#   'go',
#   'best',
#   'delivery',
#   'guy',
#   'ever',
#   '!',
#   'hope',
#   'new',
#   'guy',
#   'fucktard',
#   '...'],
#  ['http://twitpic.com/3bnas',
#   '-',
#   'oh',
#   'god',
#   '!',
#   'adorable',
#   '!',
#   'ilove',
#   'much',
#   'inspiration',
#   'nick',
#   '!'],
#  ['want', 'pineapple', '!', 'miss', 'baby'],
#  ['monday',
#   'morning',
#   'bathing',
#   '-',
#   'soooo',
#   'relaxing',
#   '!',
#   'lady',
#   'luxury',
#   'would',
#   'start',
#   'every',
#   'day',
#   'like'],
#  ["can't", 'really', 'anything', ',', '?'],
#  ['thats',
#   'love',
#   ',',
#   'shameless',
#   'lol',
#   'yet',
#   '..',
#   'aint',
#   'yet',
#   'either',
#   'lol',
#   '#frehleyfriday'],
#  ['hate',
#   ',',
#   'love',
#   '.',
#   'presentation',
#   'got',
#   'cancelled',
#   '.',
#   'got',
#   'went',
#   'work',
#   'today',
#   'pitch',
#   '!'],
#  ['driving', 'insane', '!', 'want', 'lie', '!', '!', '!'],
#  ['would',
#   'totally',
#   'take',
#   'prom',
#   '...',
#   'hadnt',
#   'already',
#   'gone',
#   'sorry',
#   'lol'],
#  ['maybe',
#   'pass',
#   'lay',
#   'making',
#   '#swineflu',
#   'illegal',
#   ',',
#   'law',
#   'abiding',
#   'citizens',
#   'get'],
#  ['love',
#   'love',
#   '.',
#   'http://bit.ly/chLaV',
#   '@',
#   'tease',
#   'baby',
#   '@',
#   'end',
#   '...',
#   'boooooo',
#   '.',
#   'still',
#   'luv',
#   'tho',
#   '.'],
#  ['finished',
#   'listening',
#   'last',
#   'days',
#   "krypton's",
#   'audio',
#   'book',
#   '!',
#   'loved',
#   '...',
#   'sad',
#   'though',
#   '...'],
#  ['girl',
#   ',',
#   'part',
#   'tour',
#   ',',
#   'would',
#   'seriously',
#   'first',
#   'line',
#   'tickets',
#   '.',
#   'sayin',
#   "'",
#   '.'],
#  ['lost', 'peacock', 'chick', 'morning'],
#  ['yea',
#   '!',
#   'headed',
#   'home',
#   'change',
#   'head',
#   'pelham',
#   '.',
#   'sad',
#   'thought',
#   '...',
#   'suposed',
#   'heading',
#   'nkotb',
#   'concert',
#   '...'],
#  ['cheese', 'counter', 'go', '!', 'thanks'],
#  ['enjoyed', 'week', 'work', ',', 'back', 'next', 'week'],
#  ['dang', 'miss', 'goodnight'],
#  ['lonely', 'need', 'company'],
#  ['gonna', 'get', 'sunshine'],
#  ["i's",
#   'sorry',
#   'listen',
#   'bats',
#   'gd',
#   '!',
#   '[',
#   'dude',
#   ',',
#   'never',
#   'got',
#   'tell',
#   ',',
#   ',',
#   'bats',
#   'amazing',
#   '<3',
#   ']'],
#  ["we're", 'gonna', 'able', 'talk'],
#  ['really', 'fucking', 'loved'],
#  ['nice', 'days', 'like', 'make', 'miss', 'alki'],
#  ['oh', 'darn', '.', 'lost', 'another', 'follower', '.'],
#  ['iight', 'gonna', 'miss', 'tonight'],
#  ['eat',
#   'sleep',
#   'draw',
#   '!',
#   ':',
#   'part',
#   'neuroanatomy',
#   'take-home',
#   'test',
#   '.',
#   ',',
#   'iï',
#   '¿',
#   '½',
#   '...',
#   ':',
#   'part',
#   'neuro',
#   '..',
#   'http://bit.ly/fXs3L'],
#  ['anywayss', 'point', 'dying', 'spend', 'summer', 'somewhere', 'hot', 'guys'],
#  ['head', 'hurt'],
#  ['back',
#   'hurts',
#   'heating',
#   'pad',
#   '...',
#   'stupid',
#   'ladder',
#   'collapse',
#   'make',
#   'fall',
#   'back',
#   '/',
#   'bum',
#   '?',
#   '?',
#   '?'],
#  ['want', 'food'],
#  ['tired', 'want', 'play', 'random', 'songs', 'gitwar', 'drama', 'essay', '.'],
#  ['loving', 'new', 'hr', 'monitor'],
#  ['supposed',
#   'coming',
#   '...',
#   'life',
#   'got',
#   'way',
#   'lol',
#   'give',
#   'friends',
#   'wild',
#   'time',
#   '!',
#   '!',
#   '!'],
#  ['ets',
#   '(',
#   'endoscopic',
#   'thoracic',
#   'sympathectomy',
#   ')',
#   'invaluable',
#   'surgical',
#   'procedure'],
#  ['sore',
#   'yesterday',
#   '.',
#   "i'm",
#   'definitely',
#   'feeling',
#   'hills',
#   '!',
#   'legs',
#   'hurt',
#   'way',
#   'booty',
#   '.',
#   'good',
#   'hurt'],
#  ['twitter', 'trippin', 'right', 'pic'],
#  ['employee',
#   'orientation',
#   'serco',
#   'yayy',
#   '..',
#   "i'm",
#   'excited',
#   '/',
#   'nervous',
#   '!',
#   '!',
#   '!',
#   'wish',
#   'luck',
#   '!'],
#  ['poor', '.', "i'm", 'bank', 'holiday', 'monday', 'today'],
#  ['beta',
#   '3.0',
#   'expired',
#   'today',
#   ',',
#   'back',
#   '2.2',
#   '.',
#   'public',
#   'release',
#   '.',
#   'miss',
#   'already'],
#  ['lovely',
#   'weekend',
#   'thank',
#   'whats',
#   'like',
#   'live',
#   '?',
#   'exciting',
#   'im',
#   'sure',
#   'night',
#   'night',
#   'xx'],
#  ['today',
#   "mother's",
#   'birthday',
#   '-',
#   'happy',
#   'birthday',
#   '&',
#   'love',
#   '!',
#   'angel',
#   'helped',
#   'much',
#   'time',
#   'life'],
#  ['-',
#   'h',
#   'lamb',
# ...
#   'either',
#   '!',
#   '!',
#   '!',
#   'grateful',
#   'blessings',
#   '!'],
#  ['pepsi', 'throwback', ',', 'taste', 'good', 'belly', '.'],
#  ['oh', 'kind'],
#  ['drinking',
#   'really',
#   'nice',
#   'coffee',
#   ',',
#   'got',
#   'go',
#   'dentist',
#   '9am',
#   'morning'],
#  ['aww', 'keep', 'sending', ';)'],
#  ['wish', 'chicago', '.'],
#  ['host', 'next', 'logies', ',', 'laughed', 'bit', 'really'],
#  ['trying',
#   'learn',
#   '"',
#   'twitter',
#   '"',
#   'thing',
#   '...',
#   "i'll",
#   'get',
#   '.',
#   'welcome',
#   'followers',
#   ',',
#   'though',
#   'im',
#   'interesting'],
#  ['laptop',
#   ',',
#   'spasy',
#   'phone',
#   ',',
#   'cat',
#   ',',
#   'music',
#   'mother',
#   'making',
#   'breakfast',
#   '!',
#   'lovage',
#   '!'],
#  ['@',
#   '@winsorandnewt',
#   'missed',
#   'party',
#   '!',
#   '!',
#   '!',
#   'bought',
#   'wine',
#   'everything',
#   '!',
#   '!',
#   '!'],
#  ['home', 'marble', 'falls', ',', 'back', 'reality'],
#  ['em',
#   ',',
#   'baby',
#   ',',
#   'starts',
#   'kindergarten',
#   '.',
#   'crazy',
#   'summer',
#   'going',
#   '.'],
#  ['thank',
#   'good',
#   'sir',
#   ',',
#   'surprisingly',
#   'good',
#   'afternoon',
#   ',',
#   'productive'],
#  ['days', 'start', 'moving', '!'],
#  ['watching', 'final', 'episode', 'boys', 'flowers'],
#  ["i've",
#   'got',
#   'sunburn',
#   'arm',
#   'better',
#   'news',
#   ',',
#   'new',
#   'guitar',
#   'hero',
#   ':',
#   'metallica',
#   'game',
#   'came',
#   'beyond',
#   'happy',
#   '.'],
#  ['love', 'joan', 'rivers', 'says', 'family', 'first', '.'],
#  ['w00t',
#   '!',
#   'glad',
#   'hear',
#   '!',
#   'though',
#   'missing',
#   'watching',
#   'outside',
#   'igloo',
#   'day'],
#  ['rain', 'almost', 'perfect', 'day', 'clothes', 'wet'],
#  ['blackberry',
#   'messenger',
#   'rocks',
#   '!',
#   'basically',
#   'im-ing',
#   'bb',
#   'users',
#   'u',
#   'add',
#   ',',
#   'like',
#   'ur',
#   'friends',
#   '.',
#   'saves',
#   'texts'],
#  ['lathargic',
#   '...',
#   'definitely',
#   'need',
#   'today',
#   'rest',
#   '.',
#   'sad',
#   'bout',
#   'havin',
#   'call',
#   'mentally',
#   'needed'],
#  ['thank',
#   'u',
#   '!',
#   '!',
#   'know',
#   "i'll",
#   'miss',
#   'u',
#   'ill',
#   'take',
#   'pics',
#   'soon',
#   'get',
#   'need',
#   'email',
#   'txt',
#   'something'],
#  ['headaaaaaaaaaaaache'],
#  ['making', 'cupcakes', 'says', "can't", 'kelli', ',', 'bad', 'sister', '.'],
#  ["can't", 'get', 'bed'],
#  ['yehey',
#   'summer',
#   '!',
#   '!',
#   'exciteeeddd',
#   '..',
#   'balme',
#   'a-a-a-a-a-alcohol',
#   '.'],
#  ['going', 'library', '.', 'miss', 'u', 'already', '!'],
#  ['fell',
#   'holdin',
#   'kales',
#   'hand',
#   'today',
#   '...',
#   'hurt',
#   'foot',
#   '&',
#   'bruised',
#   'forehead',
#   'im',
#   'klutz',
#   '!'],
#  ['effing', 'tired', 'http://bit.ly/e0ZFz'],
#  ['concert', 'tonight', 'fenwayyy', '!', 'hopefully', 'rain', 'stops'],
#  ['morning', 'sunshine'],
#  ['saaaaafe',
#   'mee',
#   '(8',
#   ')',
#   'fucking',
#   'epic',
#   'times',
#   'last',
#   'night',
#   'old',
#   'friends',
#   'new',
#   'friendships',
#   ',',
#   'good',
#   'way',
#   'kick',
#   'month',
#   '!'],
#  ['seem',
#   'photos',
#   'grandma',
#   'together',
#   'tomorrow',
#   '.',
#   'heart',
#   'breaking'],
#  ['poor',
#   'grace',
#   '!',
#   '!',
#   '!',
#   'need',
#   'date',
#   'cute',
#   'male',
#   'nurse',
#   '.'],
#  ['woo', 'hoo', '!', 'time', 'play', '"', 'name', 'twune', '"'],
#  ['poor',
#   "baby's",
#   'got',
#   'first',
#   'booboo',
#   'caused',
#   'lol',
#   'http://twitpic.com/673vt'],
#  ['wanna', 'go'],
#  ['ok',
#   '-',
#   "i'm",
#   '.',
#   'popped',
#   'say',
#   'hi',
#   'check',
#   'things',
#   '.',
#   "i'll",
#   'probably',
#   'head',
#   'guttah',
#   'later',
#   'tonight'],
#  ['dreams',
#   'give',
#   'rise',
#   'reality',
#   '.',
#   'said',
#   'walk',
#   ',',
#   'dream',
#   'fly',
#   '!',
#   'dream',
#   ',',
#   'believe',
#   ',',
#   'achieve',
#   '!'],
#  ['money', 'honey', '!', 'hehe', 'soon', 'sorry'],
#  ['http://twitpic.com/2dmtn',
#   '-',
#   'saw',
#   'pic',
#   'reminded',
#   'anna',
#   'king',
#   '..',
#   'cuuuute',
#   'little',
#   'fella'],
#  ['parents',
#   'decided',
#   'drop',
#   'tour-de-us',
#   '.',
#   'whole',
#   'family',
#   'house',
#   '.',
#   'work'],
#  ['jus',
#   'chillin',
#   'doin',
#   'hrs',
#   '.',
#   'friday',
#   'afternoons',
#   'tend',
#   'end',
#   '"',
#   'busy',
#   '"'],
#  ['creepy',
#   'first',
#   ',',
#   'really',
#   'grow',
#   'like',
#   '.',
#   'cried',
#   'like',
#   'baby',
#   'tosh',
#   'died',
#   '.'],
#  ['dont', 'like', 'random', 'gloomy', 'weather'],
#  ['helping',
#   'devin',
#   'photo',
#   'studio',
#   '.',
#   "i'm",
#   'sitting',
#   'back',
#   ',',
#   'sipping',
#   'green',
#   'apple',
#   'martini',
#   ',',
#   'watching',
#   'assemble',
#   'everything',
#   '.'],
#  ['weekend',
#   'getting',
#   'close',
#   '.',
#   'bad',
#   "i'll",
#   'stuck',
#   'north',
#   'hopefully',
#   "i'll",
#   'able',
#   'get',
#   'next',
#   'weekend',
#   'real',
#   'life',
#   'fun',
#   '.'],
#  ['someone', 'take', 'la', 'need', 'see', 'lemon', 'tree'],
#  ['thks', 'follow', ',', 'tweets', ',', 'returned', 'love'],
#  ['usual',
#   '.',
#   'two',
#   'family',
#   'parties',
#   'today',
#   '.',
#   'happy',
#   'birthday',
#   'lily',
#   '!',
#   'http://twitpic.com/4w472'],
#  ['aw',
#   ',',
#   'virtual',
#   'hug',
#   '!',
#   'lol',
#   'come',
#   'page',
#   'say',
#   'aah',
#   'congratulations',
#   '?'],
#  ['loving',
#   'sunshine',
#   '!',
#   'wish',
#   'poor',
#   'richie',
#   'would',
#   'feel',
#   'better'],
#  ['oh', 'man', ',', 'yogg', 'today', '.', 'worse', 'last', 'week', '.'],
#  ["c'mon", ',', 'like', 'superpower', 'explanation', 'better', '!', 'lol'],
#  ['http://slingalink.com/eVicE1', 'daughters', 'kindergarden', '!'],
#  ['one',
#   'talented',
#   'singer',
#   ',',
#   'dancer',
#   'actress',
#   '.',
#   'love',
#   'songs',
#   '.',
#   'look',
#   'forward',
#   'next',
#   'album',
#   '.',
#   'cheers',
#   'east',
#   '!'],
#  ['3oh', '!', 'radio', 'amazing', 'yesterday', '.'],
#  ['sitting', 'baby', '..', 'libby', 'fever', '101.0', 'shes', 'fussy'],
#  ['managed', 'find', 'bottle', "pimm's", '!', 'weather', 'go'],
#  ['cant', 'hear', 'anything', 'outta', 'left', 'ear'],
#  ['wat',
#   'stressful',
#   'week',
#   'jus',
#   'hope',
#   'everything',
#   'falls',
#   'place',
#   '4me'],
#  ['oh', ',', 'amazing', 'two', 'need', 'third', '(', 'yn', ')'],
#  ['morning', '!', '!', '!', 'blessed', 'day', '!', '!', '!'],
#  ['laughed', 'much', 'today', 'picture', 'lauren', ',', 'chest', 'hurts', '.'],
#  ['lovely',
#   'day',
#   'sky',
#   'clear',
#   'birds',
#   'singing',
#   "i'm",
#   'stuck',
#   'office',
#   'windows',
#   'hours'],
#  ['rose',
#   'city',
#   'sirens',
#   'uber',
#   'cool',
#   'last',
#   'night',
#   '!',
#   'wish',
#   'could',
#   'stayed',
#   'longer'],
#  ['going', 'back', 'manila', 'evening', '.', 'trips', 'cebu', 'bitin', '.'],
#  ['guys', ',', 'nothing', 'free', 'life', '.', 'shidduch', 'money', '?'],
#  ["i'm", 'dreading', 'hearing', 'even', 'worse', 'news', 'tonight'],
#  ['.', 'want', 'steak'],
#  ['know',
#   'enough',
#   '#sotomayor',
#   ',',
#   'made',
#   'big',
#   'boo-boo',
#   'talking',
#   'making',
#   'law',
#   '.',
#   'know',
#   'branches',
#   '?'],
#  ['<3', 'korn', '...', 'guys', 'champions', 'world'],
#  ['ur', 'shows', 'r', 'amazin', 'keep', '!', 'x'],
#  ['love', 'new', 'phone', 'hate', 'didnt', 'get', 'netbook', 'today', '...'],
#  ['officially',
#   'hit',
#   'wall',
#   ',',
#   'totally',
#   'nonfunctionalproductive',
#   'work'],
#  ["i'm",
#   '.',
#   'getting',
#   'ready',
#   'skill',
#   '.',
#   "can't",
#   'wait',
#   'fail',
#   'bio',
#   'final',
#   'yay',
#   '!',
#   'ugh',
#   ',',
#   'honor',
#   'classes',
#   'suckkkk',
#   '.',
#   '):'],
#  [':', 'visiting', 'friendster', 'facebook'],
#  ['hahah', 'hopefully', '!', 'enjoy', 'day'],
#  ['today', 'feelin', "'", 'like', 'crap'],
#  ['hurt', 'feet'],
#  ['#myweakness',
#   'loving',
#   '...',
#   'always',
#   'let',
#   'negative',
#   'people',
#   'life'],
#  ['sun',
#   'back',
#   '.',
#   'could',
#   'kind',
#   'weather',
#   'last',
#   'january',
#   'february',
#   '?',
#   'like',
#   'jackets',
#   '.'],
#  ['im', 'sad', 'work', 'today', 'cant', 'win', 'tickets'],
#  ['account', 'local', 'comic', 'store', 'ran', '4k', 'one', 'time'],
#  ['like',
#   'cheesecake',
#   'brownies',
#   '!',
#   '!',
#   '!',
#   'miss',
#   'cheesecake',
#   'brownies',
#   '...',
#   'walmart',
#   'closest',
#   'l',
#   '.',
#   '.',
#   '(',
#   ')',
#   'em'],
#  ['wish',
#   'could',
#   'bed',
#   'nine',
#   '.',
#   'never',
#   'make',
#   '3-4',
#   '.',
#   '.',
#   '#sleepdeprived',
#   '.',
#   'much',
#   '.'],
#  ['nice',
#   'day',
#   ',',
#   'looks',
#   'like',
#   'going',
#   'rain',
#   '...',
#   'getting',
#   'excited',
#   'taking',
#   'photos',
#   'get',
#   'home'],
#  ['aw',
#   "i'm",
#   'goanna',
#   'get',
#   'see',
#   'tonight',
#   'cos',
#   'leave',
#   "tot's",
#   'early',
#   'go',
#   "missy's",
#   'bday',
#   'party',
#   '.',
#   'pullin',
#   'double',
#   'haha'],
#  ['need',
#   'botox',
#   'work',
#   'lips',
#   "i'm",
#   'going',
#   'change',
#   'name',
#   'angelina',
#   'jolie',
#   ',',
#   'thought',
#   '!',
#   'sad',
#   'though',
#   'racism'],
#  ['oh', 'noes', '!', '!', 'melted', 'ice', 'cream', '=', 'want', '.'],
#  ['checking', 'say', 'good', 'monday', 'morning', '#mamo', 'friends', '...'],
#  ['think', 'im', 'going', 'wind', 'going', 'home', 'go', 'bed'],
#  ['apple',
#   'keyboard',
#   'really',
#   'cool',
#   '.',
#   'want',
#   'one',
#   '.',
#   'used',
#   'doctor'],
#  ['another', 'friday', 'night', 'nothing', '...', 'boyfriend', 'works', '1am'],
#  ['many',
#   'rules',
#   '-',
#   'expect',
#   'people',
#   'human',
#   'pic',
#   '.',
#   'pfft',
#   '.',
#   'good',
#   'morning',
#   '.',
#   'welcome',
#   'another',
#   'monday',
#   '.'],
#  ['alexxx', 'im', 'gona', 'miss', 'today', '.', 'im', 'sad', ',', 'noooooooo'],
#  ['pj', 'dayy', '...', 'doesnt', 'happen', 'veryy', 'often'],
#  ['shopping',
#   'tonight',
#   ',',
#   'cant',
#   'wait',
#   '!',
#   'lucky',
#   'bastard',
#   'already',
#   'finished',
#   'work',
#   'im',
#   'stuck',
#   'forever',
#   '!'],
#  ['laying', 'bed', 'listening', 'opticon', '.', 'miss', 'joe', 'veneck'],
#  ['kidding',
#   '?',
#   '!',
#   'looks',
#   'incredible',
#   '!',
#   '!',
#   '!',
#   'lay',
#   'swim',
#   'lot',
#   ',',
#   'stuck',
#   'cold',
#   'nyc'],
#  ['dinner', 'fam', '...', 'missed'],
#  ['would', "i'm", 'afraid', 'got', 'two', 'left', 'feet'],
#  ['feel', 'almost', 'empty', 'inside', 'today', '.', 'good', 'feeling', '.'],
#  ['hah', '!', 'thanks', '.'],
#  ["i'm", 'good', 'mood', '...', 'see', '?', "i'm", 'smiling', '!', '!', '!'],
#  ['2.5',
#   'years',
#   '&',
#   'left',
#   'dell',
#   'okc',
#   'last',
#   'time',
#   '.',
#   'geeky',
#   'girl',
#   ',',
#   'waited',
#   'cry',
#   'got',
#   'car',
#   '.',
#   'love',
#   '!'],
#  ['excited', 'taylor', 'swift', 'wednesday', '!', '!', '!'],
#  ['sounds',
#   'like',
#   'best',
#   'sort',
#   'work',
#   '!',
#   'jenni',
#   'seems',
#   'lovely',
#   ',',
#   'nice',
#   'hear',
#   'meeting',
#   "'",
#   'flesh',
#   "'",
#   '!'],
#  ['smack', 'head'],
#  ['awwww', "we're", 'gonna', 'miss', '!'],
#  ['guess',
#   '?',
#   'mom',
#   'adopted',
#   'kitty',
#   'today',
#   '(',
#   'months',
#   ')',
#   'name',
#   'corky'],
#  ['dang',
#   '!',
#   'hour',
#   'drive',
#   '!',
#   'bad',
#   'daughters',
#   '1st',
#   'bday',
#   'party',
#   'hosted',
#   'donnie'],
#  ['im', 'bannished', '...', 'work', 'till'],
#  ['daaammmnnnnn', 'wish', '.'],
#  ['cats', 'enjoy', 'sunbeams', 'open', 'windows', '.', 'think', 'counts', '.'],
#  ['feels',
#   'accomplished',
#   '!',
#   '!',
#   '!',
#   'got',
#   'lot',
#   'done',
#   'today',
#   '!',
#   'http://plurk.com/p/stns9'],
#  ['#thedailyshow', 'week'],
#  ['hahaha', 'yeah', 'see', '.', "can't", 'twitter', 'back'],
#  ['im',
#   'doofus',
#   'could',
#   'happen',
#   'wahhh',
#   '!',
#   '!',
#   '!',
#   ":'(",
#   '!',
#   '!',
#   '!',
#   'im',
#   'break',
#   '!',
#   '!'],
#  ['know', 'haha', 'night'],
#  ['p', '.', '.', 'sorry', 'ur', 'uncle'],
#  ['know', 'exactly', 'mean', "i've", 'lost', 'many', 'friends', '.', 'feel'],
#  ['also',
#   ',',
#   'toy',
#   'story',
#   'teaser',
#   'carmike',
#   '?',
#   'said',
#   'would',
#   'toy',
#   'story',
#   '!',
#   'movie',
#   'theater',
#   'fail'],
#  ['home',
#   ';',
#   'yogurt',
#   'factory',
#   ',',
#   'love',
#   'yogurt',
#   'also',
#   'hung',
#   'uncle',
#   'lucy'],
#  ['yes', 'yes', '.', 'ima', 'guna', 'lol', '.'],
#  ['love',
#   'creditcard-sized',
#   'memory',
#   'sticks',
#   '.',
#   'microsoft',
#   'keeps',
#   'sending'],
#  ['wish',
#   'coming',
#   'australia',
#   '&',
#   'new',
#   'zealand',
#   'sticky',
#   'tour',
#   'ant'],
#  ['lol',
#   'cut',
#   'bangs',
#   'like',
#   'kate',
#   'hudson',
#   'bride',
#   'wars',
#   'months',
#   'ago',
#   'super',
#   'cute',
#   '.',
#   'looks',
#   'diff',
#   'time'],
#  ['miss', 'tugger', 'misto', 'last', 'night', 'amazing', '<3', 'close', ":')"],
#  ['paper', 'work', 'friday', 'afternoo'],
#  ['may',
#   'ask',
#   'bluegrass',
#   'means',
#   '?',
#   'sorry',
#   'advance',
#   'looking',
#   'bit',
#   'silly',
#   'asking'],
#  ["oddo's", 'grandfather', 'passed', 'away', 'sleep'],
#  ['guinness',
#   'got',
#   "'",
#   'new',
#   "'",
#   'toys',
#   'mom',
#   'dads',
#   'house',
#   '.',
#   'hooray',
#   'free',
#   'stuff'],
#  ['melissa_leah', ':', 'car', 'wont', 'start', '...'],
#  ['hehehe', '.', ')', '`', 'nice'],
#  ['luv',
#   'urs',
#   '!',
#   'admitting',
#   'niley',
#   'kiss',
#   '(:',
#   'change',
#   'minds',
#   'haha',
#   '&',
#   'demi',
#   '/',
#   'sterling',
#   '(:',
#   'jemi',
#   'still',
#   'cute'],
#  ['bwarg', '.', "can't", 'sleep', ',', 'tired', 'drawing', '.'],
#  ["i'm", 'awake', 'others', 'sleep'],
#  ['think', 'blog', 'list'],
#  ['awwww',
#   '...',
#   'thanks',
#   '!',
#   '!',
#   ';)',
#   'unfortunately',
#   ',',
#   'everything',
#   'closes',
#   '4pm',
#   'sweden',
#   'friday',
#   '.',
#   'presentation',
#   '9am',
#   'monday',
#   '.'],
#  ['missed',
#   '.',
#   'today',
#   'greatest',
#   'day',
#   'ever',
#   '.',
#   'im',
#   'burnt',
#   'shit',
#   'lmfao',
#   '.',
#   'nice',
#   'tan',
#   '.',
#   'rides',
#   'hrs',
#   '!',
#   '<3'],
#  ['haha',
#   'nice',
#   '!',
#   'heard',
#   'sweet',
#   'hotel',
#   '.',
#   'another',
#   'note',
#   ',',
#   'good',
#   'game',
#   'last',
#   'night'],
#  ['14:14',
#   '..',
#   'someone',
#   'thinking',
#   'good',
#   'luck',
#   'lynny',
#   'tattoo',
#   ';)'],
#  ['im',
#   'watching',
#   'tv',
#   'home',
#   'wishing',
#   'could',
#   'get',
#   'chicken',
#   'shish',
#   'delivered',
#   'go',
#   'enough',
#   'pennies'],
#  ['hey',
#   'chick',
#   '!',
#   'going',
#   'ja',
#   'pick',
#   'hot',
#   'guys',
#   'eat',
#   'jerk',
#   'pork',
#   'festival',
#   '?',
#   'well',
#   'already',
#   'hot',
#   'guy'],
#  ['drink', 'marc', 'izzy', 'sleepin', 'woot', 'woot', '!'],
#  ['really',
#   '?',
#   '!',
#   '?',
#   '!',
#   'looks',
#   'like',
#   'going',
#   'rain',
#   'gray',
#   '...',
#   'la',
#   'bummer',
#   'sumtimes'],
#  [':',
#   'let',
#   '!',
#   'mri',
#   'today',
#   ',',
#   'neurosurgeon',
#   'order',
#   'it--which',
#   'means',
#   'come',
#   'back',
#   'okc',
#   'soon',
#   '&',
#   'nothing',
#   'new'],
#  ['mmmm', '...', 'macrina', 'bakery', '.'],
#  ['unfortunately',
#   'us',
#   'looks',
#   'like',
#   'funny',
#   'people',
#   'twitter',
#   'move',
#   'fb',
#   'start',
#   '...',
#   'flitter'],
#  ['sleep', '...', 'take', 'two', '...', 'better', 'work', '!'],
#  ['good', 'good', 'sched', 'sadly'],
#  ['bad', 'catch', 'brazil', 'good', 'luck', 'show', '!', 'amazing', '!'],
#  ['hey', 'guys', "i'm", 'back', 'work', '..', 'kinda', 'horrible'],
#  ['glad', 'friday', '.', 'got', 'work', "i'm", 'tired', '.'],
#  ['congratulations', 'chap', '!', 'pass', 'love', 'claude'],
#  ['wth', 'happening', 'neck', '.', 'definitely', 'stiff', 'neck', ':|'],
#  ['life', 'good', '.', 'much', 'greater', 'thursday', '5pm', '!'],
#  ['ikr',
#   '?',
#   'parents',
#   'take',
#   'cake',
#   'tho',
#   ',',
#   'grocery',
#   'shop',
#   'go',
#   'eat',
#   'time',
#   '...'],
#  ['hav', 'followers', '!'],
#  ['yay', 'full-term', '!', '!'],
#  ['life',
#   'sad',
#   '..',
#   'reminder',
#   'go',
#   'phone',
#   'recharge',
#   'toothbrush',
#   '!'],
#  ['home', '.', 'got', 'nice', 'plugs', 'chipotle'],
#  ['new', 'week', '=', 'new', 'legend', 'make', '.'],
#  ['disappointing'],
#  ['come', 'online', '!', 'need', 'someone', 'talk'],
#  [':',
#   'know',
#   '!',
#   '!',
#   'im',
#   'excited',
#   '.',
#   'cant',
#   'go',
#   'earlierrr',
#   'afternoon',
#   '?',
#   'love',
#   'tooz',
#   '<3'],
#  ['tooo', '!', '!', 'wish', 'could', 'get'],
#  ["he's",
#   'gonna',
#   'mothers',
#   'day',
#   'ever',
#   'notice',
#   'papa',
#   'looks',
#   'like',
#   'squiggy',
#   'laverne',
#   'snd',
#   'shirley',
#   '.',
#   'love',
#   '.'],
#  ['wow',
#   ',',
#   'bed',
#   'comfy',
#   '&',
#   'nap',
#   'much',
#   'short',
#   '.',
#   'getting',
#   'work',
#   '=',
#   'want',
#   '.'],
#  ['jay', "leno's", 'last', 'show', 'tonight'],
#  ['first', 'day', 'new', 'job', '!', 'yeah', '!'],
#  ['know', '!', '!', '!', 'join', 'freekin', 'club', '!', '!', '!'],
#  ['love',
#   'movie',
#   'grease',
#   '!',
#   "can't",
#   'believe',
#   'jeff',
#   'conaway',
#   'guy',
#   'played',
#   'kenickie',
#   '...',
#   'sad',
#   'see',
#   'celebrity',
#   'rehab'],
#  ['good', 'morning', ',', 'gents', '!', 'ya', 'today', '?'],
#  ...]

# %%
train_doc2vec = [TaggedDocument((d), tags=[str(i)]) for i, d in enumerate(train_data)]

# %%
model = Doc2Vec(vector_size=50, alpha=0.025, min_count=5, dm =1, epochs=100)
model.build_vocab(train_doc2vec)
model.train(train_doc2vec, total_examples=model.corpus_count, epochs=model.epochs)

# %% [markdown]
# - Doc2vec’s infer_vector function can be used
# to infer the vector representation for a given text using a pre-trained model.

# %%
train_vectors =  [model.infer_vector(list_of_tokens) for list_of_tokens in train_data]
test_vectors = [model.infer_vector(list_of_tokens) for list_of_tokens in test_data]

# %%
#Use any regular classifier like logistic regression
from sklearn.linear_model import LogisticRegression

myclass = LogisticRegression(class_weight="balanced") #because classes are not balanced. 
myclass.fit(train_vectors, train_cats)

preds = myclass.predict(test_vectors)
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(test_cats, preds))
# Out:
#               precision    recall  f1-score   support
#
#    happiness       0.47      0.38      0.42       694
#         love       0.35      0.54      0.43       534
#      sadness       0.73      0.64      0.68      1243
#
#     accuracy                           0.55      2471
#    macro avg       0.52      0.52      0.51      2471
# weighted avg       0.57      0.55      0.55      2471
